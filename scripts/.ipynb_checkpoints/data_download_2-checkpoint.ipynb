# %% [markdown]
# # Downloading data
# ## Green spaces

# %%
import warnings
warnings.filterwarnings("ignore", category=FutureWarning)
warnings.filterwarnings("ignore", category=UserWarning)

# %%
import geopandas as gpd
from ohsome import OhsomeClient
import pandas as pd
import warnings
warnings.filterwarnings("ignore", category=FutureWarning)
warnings.filterwarnings("ignore", category=UserWarning)

client = OhsomeClient()

# Load the GeoJSON file with GeoPandas
bpolys = gpd.read_file("../data/input/barcelona.geojson")

# Define which OSM features should be considered green spaces.
filter_greenspaces = "leisure=common or leisure=dog_park or leisure=firepit or leisure=fishing or leisure=garden or leisure=golf_course or leisure=miniature_golf or leisure=nature_reserve or leisure=park or leisure=picnic_table or leisure=pitch"

# Make the request to the ohsome API for green spaces
response_greenspaces = client.elements.geometry.post(
    bpolys=bpolys,
    filter=filter_greenspaces,
    properties="tags,metadata"
)

# Convert the response to a GeoDataFrame for green spaces
greenspaces_df = response_greenspaces.as_dataframe()
greenspaces_df = greenspaces_df[greenspaces_df.geometry.type == 'Polygon']

# Add a unique ID column starting from 1 and place it at the beginning
greenspaces_df.insert(0, 'id', range(1, len(greenspaces_df) + 1))

# Display and plot the green spaces GeoDataFrame
display(greenspaces_df)

# Save the green spaces GeoDataFrame to a GeoJSON file
greenspaces_df.to_file("../data/output/greenspaces.geojson", driver='GeoJSON')
# Out:
#                                          id  \
# @osmId            @snapshotTimestamp
# relation/10678371 2024-04-02 09:00:00     1
# relation/11059349 2024-04-02 09:00:00     2
# relation/11516851 2024-04-02 09:00:00     3
# relation/11775680 2024-04-02 09:00:00     4
# relation/12077275 2024-04-02 09:00:00     5
# ...                                     ...
# way/993505008     2024-04-02 09:00:00  2983
# way/993509773     2024-04-02 09:00:00  2984
# way/995794964     2024-04-02 09:00:00  2985
# way/997401987     2024-04-02 09:00:00  2986
# way/999036465     2024-04-02 09:00:00  2987
#
#                                                                                 geometry  \
# @osmId            @snapshotTimestamp
# relation/10678371 2024-04-02 09:00:00  POLYGON ((2.19084 41.39947, 2.19057 41.39927, ...
# relation/11059349 2024-04-02 09:00:00  POLYGON ((2.18925 41.38551, 2.18924 41.38554, ...
# ...

# %% [markdown]
# ## public spaces

# %%
import geopandas as gpd
from ohsome import OhsomeClient
import pandas as pd

client = OhsomeClient()

# Load the GeoJSON file with GeoPandas
bpolys = gpd.read_file("../data/input/barcelona.geojson")

# Define which OSM features should be considered green spaces.
filter_publicspaces = "leisure=adult_gaming_centre or leisure=amusement_arcade or leisure=bandstand or leisure=bathing_place or leisure=beach_resort or leisure=bowling_alley or leisure=dance or leisure=disc_golf_course or leisure=escape_game or leisure=fitness_centre or leisure=fitness_station or leisure=hackerspace or leisure=playground or leisure=resort or leisure=sports_centre or leisure=sports_hall or leisure=stadium or leisure=swimming_area or leisure=swimming_pool"

# Make the request to the ohsome API for green spaces
response_publicspaces = client.elements.geometry.post(
    bpolys=bpolys,
    filter=filter_publicspaces,
    properties="tags,metadata"
)

# Convert the response to a GeoDataFrame for public spaces
publicspaces_df = response_publicspaces.as_dataframe()
# Filter out LineString geometries
publicspaces_df = publicspaces_df[publicspaces_df.geometry.type.isin(['Point', 'Polygon'])]

# Add a unique ID column starting from 1 and place it at the beginning
publicspaces_df.insert(0, 'id', range(1, len(publicspaces_df) + 1))

# Display and plot the public spaces GeoDataFrame
display(publicspaces_df)

# Save the green spaces GeoDataFrame to a GeoJSON file
publicspaces_df.to_file("../data/output/publicspaces.geojson", driver='GeoJSON')
# Out:
#                                         id  \
# @osmId           @snapshotTimestamp
# node/10039721318 2024-04-02 09:00:00     1
# node/10039732419 2024-04-02 09:00:00     2
# node/10039866517 2024-04-02 09:00:00     3
# node/10041423617 2024-04-02 09:00:00     4
# node/10046898818 2024-04-02 09:00:00     5
# ...                                    ...
# way/995405346    2024-04-02 09:00:00  2508
# way/996540259    2024-04-02 09:00:00  2509
# way/998181919    2024-04-02 09:00:00  2510
# way/998181948    2024-04-02 09:00:00  2511
# way/998197600    2024-04-02 09:00:00  2512
#
#                                                                                geometry  \
# @osmId           @snapshotTimestamp
# node/10039721318 2024-04-02 09:00:00                           POINT (2.20320 41.43927)
# node/10039732419 2024-04-02 09:00:00                           POINT (2.20661 41.43620)
# node/10039866517 2024-04-02 09:00:00                           POINT (2.19463 41.42768)
# ...

# %% [markdown]
# ## public buildings

# %%
import geopandas as gpd
from ohsome import OhsomeClient
import pandas as pd

client = OhsomeClient()
#public_building

# Load the GeoJSON file with GeoPandas
bpolys = gpd.read_file("../data/input/barcelona.geojson")

# Define which OSM features should be considered
filter_public_building = "building=public or building=civic or building=government"

# Make the request to the ohsome API for green spaces
response_public_building = client.elements.geometry.post(
    bpolys=bpolys,
    filter=filter_public_building,
    properties="tags,metadata"
)

# Convert the response to a GeoDataFrame for public_building
public_building_df = response_public_building.as_dataframe()
public_building_df = public_building_df[public_building_df.geometry.type == 'Polygon']

# Add a unique ID column starting from 1 and place it at the beginning
public_building_df.insert(0, 'id', range(1, len(public_building_df) + 1))

# Display and plot the public building GeoDataFrame
display(public_building_df)

# Save the public_building GeoDataFrame to a GeoJSON file
public_building_df.to_file("../data/output/public_building.geojson", driver='GeoJSON')
# Out:
#                                          id  \
# @osmId            @snapshotTimestamp
# relation/10108796 2024-04-02 09:00:00     1
# relation/10127874 2024-04-02 09:00:00     2
# relation/10175494 2024-04-02 09:00:00     3
# relation/10657914 2024-04-02 09:00:00     4
# relation/10657996 2024-04-02 09:00:00     5
# ...                                     ...
# way/889102840     2024-04-02 09:00:00   999
# way/902488874     2024-04-02 09:00:00  1000
# way/917143851     2024-04-02 09:00:00  1001
# way/970656655     2024-04-02 09:00:00  1002
# way/992232142     2024-04-02 09:00:00  1003
#
#                                                                                 geometry  \
# @osmId            @snapshotTimestamp
# relation/10108796 2024-04-02 09:00:00  POLYGON ((2.17368 41.37365, 2.17371 41.37371, ...
# relation/10127874 2024-04-02 09:00:00  POLYGON ((2.18836 41.40896, 2.18851 41.40884, ...
# ...

# %%
import geopandas as gpd
from ohsome import OhsomeClient

client = OhsomeClient()

# Load the GeoJSON file with GeoPandas
bpolys = gpd.read_file("../data/input/barcelona.geojson")

# Define which OSM features should be considered for ramps
filter_ramp = "ramp=*"

# Make the request to the ohsome API for ramps
response_ramp = client.elements.geometry.post(
    bpolys=bpolys,
    filter=filter_ramp,
    properties="tags,metadata"
)

# Convert the response to a GeoDataFrame for ramps
ramp_df = response_ramp.as_dataframe()

# Add a unique ID column starting from 1 and place it at the beginning
ramp_df.insert(0, 'id', range(1, len(ramp_df) + 1))

# Display and plot the GeoDataFrame for ramps
display(ramp_df)

# Save the GeoDataFrame for ramps to a GeoJSON file
ramp_df.to_file("../data/output/ramp.geojson", driver='GeoJSON')
# Out:
#                                      id  \
# @osmId         @snapshotTimestamp
# way/1000721841 2024-04-02 09:00:00    1
# way/1000721842 2024-04-02 09:00:00    2
# way/1002323611 2024-04-02 09:00:00    3
# way/1003907978 2024-04-02 09:00:00    4
# way/1004714826 2024-04-02 09:00:00    5
# ...                                 ...
# way/978702487  2024-04-02 09:00:00  712
# way/983161700  2024-04-02 09:00:00  713
# way/983161702  2024-04-02 09:00:00  714
# way/987517927  2024-04-02 09:00:00  715
# way/988537511  2024-04-02 09:00:00  716
#
#                                                                              geometry  \
# @osmId         @snapshotTimestamp
# way/1000721841 2024-04-02 09:00:00  LINESTRING (2.15206 41.41508, 2.15206 41.41506...
# way/1000721842 2024-04-02 09:00:00  LINESTRING (2.15193 41.41501, 2.15191 41.41502...
# way/1002323611 2024-04-02 09:00:00    LINESTRING (2.14440 41.41998, 2.14460 41.42009)
# ...

# %% [markdown]
# # Accessibility

# %% [markdown]
# access should be yes or costumers or destination
#
# wheelchair yes or limited or designated
#
# ## Wheelchair accessibility

# %% [markdown]
# ## Greenspaces
# ### first with definitive information being able to access with a wheelchair

# %%
import geopandas as gpd

def wheelchair(layer, feature, values):
    bpolys = gpd.read_file(layer)
    filtered_greenspaces = bpolys[bpolys[feature].isin(values)]
    output_path = output
    filtered_greenspaces.to_file(output_path, driver="GeoJSON")

# %%
layer = "../data/output/greenspaces.geojson"
feature = "wheelchair"
values = ["yes", "limited", "designated"]
output = "../data/output/wheelchair_greenspace.geojson"

wheelchair(layer, feature, values)

# %% [markdown]
# those are only 27, therefore we will next get the ones with definitive no and the ones with no information.

# %%
import geopandas as gpd

layer = "../data/output/greenspaces.geojson"
feature = "wheelchair"
values = ["no"]
output = "../data/output/no_wheelchair_greenspace.geojson"

wheelchair(layer, feature, values)

# %% [markdown]
# no wheelchair are only 5. still a over 2000 missing. Those are the ones with no information:

# %%
import geopandas as gpd

def null_wheelchair(layer, feature, output_path):
    bpolys = gpd.read_file(layer)
    filtered_greenspaces = bpolys[bpolys[feature].isna()]
    filtered_greenspaces.to_file(output_path, driver="GeoJSON")

# %%
layer = "../data/output/greenspaces.geojson"
feature = "wheelchair"
output = "../data/output/null_wheelchair_greenspace.geojson"

null_wheelchair(layer, feature, output)
# Idee ist dann die Funktion für Barcelona und München aufzurufen

# %% [markdown]
# Um sich jetzt anzunähern: Alle greeenspaces, die eine ramp in sich haben, werden als mit wheelchair accessible aufgenommen.

# %%
import geopandas as gpd

# Load the GeoJSON files for ramps and green spaces
ramps = gpd.read_file("../data/output/ramp.geojson")
greenspaces = gpd.read_file("../data/output/greenspaces.geojson")

# Perform a spatial join to find ramps within green spaces
joined_data = gpd.sjoin(greenspaces, ramps, how="inner", op="intersects")

# Extract unique green space indices that have at least one ramp within them
green_spaces_with_ramps_indices = joined_data.index.unique()

# Filter the green spaces GeoDataFrame to include only those with ramps
greenspaces_with_ramps = greenspaces.loc[green_spaces_with_ramps_indices]

# Save the resulting GeoDataFrame as a new GeoJSON file
output_path = "../data/output/greenspaces_with_ramps.geojson"
greenspaces_with_ramps.to_file(output_path, driver="GeoJSON")

# %% [markdown]
# Zusammenführen der beiden layer die accessible mit wheelchair sind: sind immerhin 97 statt zu Beginn 27

# %%
import geopandas as gpd

# Load the GeoJSON files for wheelchair accessible green spaces and green spaces with ramps
wheelchair_greenspaces = gpd.read_file("../data/output/wheelchair_greenspace.geojson")
greenspaces_with_ramps = gpd.read_file("../data/output/greenspaces_with_ramps.geojson")

# Concatenate the two GeoDataFrames
combined_greenspaces = gpd.GeoDataFrame(pd.concat([wheelchair_greenspaces, greenspaces_with_ramps], ignore_index=True))

# Remove duplicate geometries
combined_greenspaces_unique = combined_greenspaces.drop_duplicates(subset=['geometry'])

# Save the resulting GeoDataFrame as a new GeoJSON file
output_path = "../data/output/combined_greenspaces_wheelchair.geojson"
combined_greenspaces_unique.to_file(output_path, driver="GeoJSON")

# %% [markdown]
# ## Wheelchair access to public buildings

# %%
import geopandas as gpd

layer = "../data/output/public_building.geojson"
feature = "wheelchair"
values = ["yes", "limited"]
output = "../data/output/wheelchair_public_building.geojson"

wheelchair(layer, feature, values)

# %% [markdown]
# sind nur 33 von 1003 public buildings

# %%
layer = "../data/output/public_building.geojson"
feature = "wheelchair"
output = "../data/output/null_wheelchair_public_buildings.geojson"

null_wheelchair(layer, feature, output)

# %% [markdown]
# das sind 968. welche definitv no?

# %%
layer = "../data/output/public_building.geojson"
feature = "wheelchair"
values = ["no"]
output = "../data/output/no_wheelchair_public_building.geojson"

wheelchair(layer, feature, values)

# %% [markdown]
# 2 haben ein no. Die meisten einfach keine Info

# %% [markdown]
# ## Wheelchair access to public spaces

# %%
import geopandas as gpd

layer = "../data/output/publicspaces.geojson"
feature = "wheelchair"
values = ["yes", "limited"]
output = "../data/output/wheelchair_publicspaces.geojson"

wheelchair(layer, feature, values)

# %%
layer = "../data/output/publicspaces.geojson"
feature = "wheelchair"
output = "../data/output/null_wheelchair_publicspaces.geojson"

null_wheelchair(layer, feature, output)

# %%
layer = "../data/output/publicspaces.geojson"
feature = "wheelchair"
values = ["no"]
output = "../data/output/no_wheelchair_publicspaces.geojson"

wheelchair(layer, feature, values)

# %% [markdown]
# ## Konsumarmer Zugang
#
# ### für public spaces

# %%
import geopandas as gpd

def access(layer, feature, values):
    bpolys = gpd.read_file(layer)
    filtered_greenspaces = bpolys[bpolys[feature].isin(values)]
    output_path = output
    filtered_greenspaces.to_file(output_path, driver="GeoJSON")

# %%
layer = "../data/output/publicspaces.geojson"
feature = "access"
values = ["yes"]
output = "../data/output/free_access_publicspace.geojson"

access(layer, feature, values)

# %% [markdown]
# Konsum

# %%
layer = "../data/output/publicspaces.geojson"
feature = "access"
values = ["customers", "destination"]
output = "../data/output/buy_access_greenspace.geojson"

access(layer, feature, values)

# %% [markdown]
# Rest ist private

# %% [markdown]
# ### public buildings
# (hoffentlich alle?)

# %%
layer = "../data/output/public_building.geojson"
feature = "access"
values = ["yes"]
output = "../data/output/free_access_public_building.geojson"

access(layer, feature, values)

# %%
layer = "../data/output/public_building.geojson"
feature = "access"
values = ["customers", "destination"]
output = "../data/output/buy_access_public_building.geojson"

access(layer, feature, values)

# %% [markdown]
# 2, aber falsch gemappt zum klettern und schwimmen

# %% [markdown]
# ### green spaces

# %%
layer = "../data/output/greenspaces.geojson"
feature = "access"
values = ["yes"]
output = "../data/output/free_access_greenspaces.geojson"

access(layer, feature, values)

# %%
layer = "../data/output/greenspaces.geojson"
feature = "access"
values = ["customers", "destination"]
output = "../data/output/buy_access_greenspaces.geojson"

access(layer, feature, values)

# %% [markdown]
# pitches sind buy access weil "Bereich, der für die Ausübung einer bestimmten Sportart vorgesehen und normalerweise mit entsprechenden Markierungen versehen ist."

# %% [markdown]
# # Isochrones
#
# ## Biking

# %%
import json
import time
import os
import geopandas as gpd
from openrouteservice import Client
from openrouteservice.exceptions import ApiError

def calculate_isochrones_bike(input_file, output_path, output_filename, print_statement, profile):
    # Load poi data with GeoPandas
    poi = gpd.read_file(input_file)

    # Calculate centroids for each polygon
    poi['centroid'] = poi['geometry'].centroid

    # Change CRS to EPSG:4326
    poi = poi.to_crs("EPSG:4326")

    # Get the name of the ID column
    poi_id_column = 'id'  # Assuming the column name is 'id'

    # Initialize OpenRouteService client
    api_key = "5b3ce3597851110001cf6248ec8fc0286b4a4fd1a90fc8108327d823"  # Replace with your actual API key
    client = Client(key=api_key)

    # Define parameters for isochrone calculation
    profile = 'cycling-regular'
    range_type = 'time'
    range_seconds = [900, 1800]  # 15 and 30 Minutes

    # Create the directory if it doesn't exist
    os.makedirs(output_path, exist_ok=True)

    # Function to calculate isochrones with retry mechanism
    def calculate_isochrones_with_retry(coordinate):
        retries = 3  # Number of retries
        for attempt in range(retries):
            try:
                isochrones = client.isochrones(locations=[coordinate], profile=profile, range_type=range_type, range=range_seconds, attributes=['total_pop'])
                return isochrones
            except ApiError as e:
                if "rate limit exceeded" in str(e):
                    print(f"Rate limit exceeded. Retrying in 10 seconds...")
                    time.sleep(10)  # Retry after 10 seconds for rate limit errors
                elif "Unable to build an isochrone map" in str(e):
                    print(f"Unable to build an isochrone map for POI. Skipping...")
                    return None
                else:
                    raise e  # Re-raise the exception if it's not related to rate limit exceeded
        return None

    # Iterate over poi and calculate isochrones
    for idx, row in poi.iterrows():
        # Get centroid coordinates of the poi
        lon, lat = row['centroid'].x, row['centroid'].y
        coordinate = (lon, lat)

        # Calculate isochrones with retry mechanism
        isochrones = calculate_isochrones_with_retry(coordinate)
        if isochrones is None:
            continue  # Skip the poi if isochrones cannot be calculated
            
        # Get the poi ID from the column
        poi_id = row[poi_id_column]

        # Add poi ID to each isochrone feature
        for feature in isochrones['features']:
            feature['properties']['poi_id'] = poi_id

        # Save isochrones data to file
        output_file_path = os.path.join(output_path, f'{output_filename}_{idx + 1}.geojson')
        
        with open(output_file_path, 'w') as output_file:
            json.dump(isochrones, output_file)

        print(print_statement.format(idx))

        # Rate limit handling
        time.sleep(3)  # Add a small delay to avoid rate limits and respect the rate limit

    print("Isochrone calculation completed.")

# %% [markdown]
# ### Public Buildings

# %%
# Example usage:
input_file = '../data/output/wheelchair_public_building.geojson'
output_path = '../data/output/barcelona_isochrones_bike/'
output_filename = 'b_iso_bike_pb'
print_statement = "Isochrones calculated for POI {}"

calculate_isochrones_bike(input_file, output_path, output_filename, print_statement, profile)
# Out:
# /var/folders/_n/_djf18r57q3482fkc8bbytk80000gn/T/ipykernel_27883/3915677967.py:13: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   poi['centroid'] = poi['geometry'].centroid
# Isochrones calculated for POI 0
# Isochrones calculated for POI 1
# Isochrones calculated for POI 2
# Isochrones calculated for POI 3
# Isochrones calculated for POI 4
# Isochrones calculated for POI 5
# Isochrones calculated for POI 6
# Isochrones calculated for POI 7
# Isochrones calculated for POI 8
# Isochrones calculated for POI 9
# Isochrones calculated for POI 10
# Isochrones calculated for POI 11
# Isochrones calculated for POI 12
# Isochrones calculated for POI 13
# Isochrones calculated for POI 14
# Isochrones calculated for POI 15
# Isochrones calculated for POI 16
# Isochrones calculated for POI 17
# Isochrones calculated for POI 18
# ...

# %% [markdown]
# ### Greenspaces

# %%
input_file = '../data/output/combined_greenspaces_wheelchair.geojson'
output_path = '../data/output/barcelona_isochrones_bike_greenspaces/'
output_filename = 'b_iso_bike_green'
print_statement = "Isochrones calculated for POI {}"

calculate_isochrones_bike(input_file, output_path, output_filename, print_statement, profile)
# Out:
# /var/folders/_n/_djf18r57q3482fkc8bbytk80000gn/T/ipykernel_27883/3915677967.py:13: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   poi['centroid'] = poi['geometry'].centroid
# Isochrones calculated for POI 0
# Unable to build an isochrone map for POI. Skipping...
# Isochrones calculated for POI 2
# Isochrones calculated for POI 3
# Isochrones calculated for POI 4
# Isochrones calculated for POI 5
# Isochrones calculated for POI 6
# Isochrones calculated for POI 7
# Isochrones calculated for POI 8
# Isochrones calculated for POI 9
# Isochrones calculated for POI 10
# Isochrones calculated for POI 11
# Isochrones calculated for POI 12
# Isochrones calculated for POI 13
# Isochrones calculated for POI 14
# Isochrones calculated for POI 15
# Isochrones calculated for POI 16
# Isochrones calculated for POI 17
# Isochrones calculated for POI 18
# ...

# %% [markdown]
# ### public spaces

# %%
input_file = '../data/output/wheelchair_publicspaces.geojson'
output_path = '../data/output/barcelona_isochrones_bike_greenspaces/'
output_filename = 'b_iso_bike_ps_wheelchair'
print_statement = "Isochrones calculated for POI {}"

calculate_isochrones_bike(input_file, output_path, output_filename, print_statement, profile)
# Out:
# /var/folders/_n/_djf18r57q3482fkc8bbytk80000gn/T/ipykernel_27883/3915677967.py:13: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   poi['centroid'] = poi['geometry'].centroid
# Isochrones calculated for POI 0
# Isochrones calculated for POI 1
# Isochrones calculated for POI 2
# Isochrones calculated for POI 3
# Isochrones calculated for POI 4
# Isochrones calculated for POI 5
# Isochrones calculated for POI 6
# Isochrones calculated for POI 7
# Unable to build an isochrone map for POI. Skipping...
# Isochrones calculated for POI 9
# Isochrones calculated for POI 10
# Isochrones calculated for POI 11
# Isochrones calculated for POI 12
# Isochrones calculated for POI 13
# Isochrones calculated for POI 14
# Isochrones calculated for POI 15
# Isochrones calculated for POI 16
# Isochrones calculated for POI 17
# Isochrones calculated for POI 18
# ...

# %%
# Das sind sehr viele, sicher?
'''input_file = '../data/output/null_wheelchair_publicspaces.geojson'
output_path = '../data/output/barcelona_isochrones_bike_greenspaces/'
output_filename = 'b_iso_bike_ps_null'
print_statement = "Isochrones calculated for POI {}"

calculate_isochrones_bike(input_file, output_path, output_filename, print_statement, profile)'''

# %% [markdown]
# ## Walking

# %%
import json
import time
import os
import geopandas as gpd
from openrouteservice import Client
from openrouteservice.exceptions import ApiError

def calculate_isochrones_walk(input_file, output_path, output_filename, print_statement, profile):
    # Load poi data with GeoPandas
    poi = gpd.read_file(input_file)

    # Calculate centroids for each polygon
    poi['centroid'] = poi['geometry'].centroid

    # Change CRS to EPSG:4326
    poi = poi.to_crs("EPSG:4326")
    
    # Get the name of the ID column
    poi_id_column = 'id'  # Assuming the column name is 'id'

    # Initialize OpenRouteService client
    api_key = "5b3ce3597851110001cf6248ec8fc0286b4a4fd1a90fc8108327d823"  # Replace with your actual API key
    client = Client(key=api_key)

    # Define parameters for isochrone calculation
    profile = 'foot-walking'
    range_type = 'time'
    range_seconds = [900, 1800]  # 15 and 30 Minutes

    # Create the directory if it doesn't exist
    os.makedirs(output_path, exist_ok=True)

    # Function to calculate isochrones with retry mechanism
    def calculate_isochrones_with_retry(coordinate):
        retries = 3  # Number of retries
        for attempt in range(retries):
            try:
                isochrones = client.isochrones(locations=[coordinate], profile=profile, range_type=range_type, range=range_seconds, attributes=['total_pop'])
                return isochrones
            except ApiError as e:
                if "rate limit exceeded" in str(e):
                    print(f"Rate limit exceeded. Retrying in 10 seconds...")
                    time.sleep(10)  # Retry after 10 seconds for rate limit errors
                elif "Unable to build an isochrone map" in str(e):
                    print(f"Unable to build an isochrone map for POI. Skipping...")
                    return None
                else:
                    raise e  # Re-raise the exception if it's not related to rate limit exceeded
        return None

    # Iterate over poi and calculate isochrones
    for idx, row in poi.iterrows():
        # Get centroid coordinates of the poi
        lon, lat = row['centroid'].x, row['centroid'].y
        coordinate = (lon, lat)

        # Calculate isochrones with retry mechanism
        isochrones = calculate_isochrones_with_retry(coordinate)
        if isochrones is None:
            continue  # Skip the poi if isochrones cannot be calculated
            
        # Get the poi ID from the column
        poi_id = row[poi_id_column]            

        # Add poi ID to each isochrone feature
        for feature in isochrones['features']:
            feature['properties']['poi_id'] = poi_id

        # Save isochrones data to file
        output_file_path = os.path.join(output_path, f'{output_filename}_{idx + 1}.geojson')
        
        with open(output_file_path, 'w') as output_file:
            json.dump(isochrones, output_file)

        print(print_statement.format(idx))

        # Rate limit handling
        time.sleep(3)  # Add a small delay to avoid rate limits and respect the rate limit

    print("Isochrone calculation completed.")

# %% [markdown]
# ### Public Building

# %%
input_file = '../data/output/wheelchair_public_building.geojson'
output_path = '../data/output/barcelona_isochrones_foot_public_building/'
output_filename = 'b_iso_foot_pb'
print_statement = "Isochrones calculated for POI {}"

calculate_isochrones_walk(input_file, output_path, output_filename, print_statement, profile)
# Out:
# /var/folders/_n/_djf18r57q3482fkc8bbytk80000gn/T/ipykernel_27883/3880632938.py:13: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   poi['centroid'] = poi['geometry'].centroid
# Isochrones calculated for POI 0
# Isochrones calculated for POI 1
# Isochrones calculated for POI 2
# Isochrones calculated for POI 3
# Isochrones calculated for POI 4
# Isochrones calculated for POI 5
# Isochrones calculated for POI 6
# Isochrones calculated for POI 7
# Isochrones calculated for POI 8
# Isochrones calculated for POI 9
# Isochrones calculated for POI 10
# Isochrones calculated for POI 11
# Isochrones calculated for POI 12
# Isochrones calculated for POI 13
# Isochrones calculated for POI 14
# Isochrones calculated for POI 15
# Isochrones calculated for POI 16
# Isochrones calculated for POI 17
# Isochrones calculated for POI 18
# ...

# %% [markdown]
# ### Greenspaces

# %%
input_file = '../data/output/combined_greenspaces_wheelchair.geojson'
output_path = '../data/output/barcelona_isochrones_foot_greenspaces/'
output_filename = 'b_iso_foot_green'
print_statement = "Isochrones calculated for POI {}"

calculate_isochrones_walk(input_file, output_path, output_filename, print_statement, profile)
# Out:
# /var/folders/_n/_djf18r57q3482fkc8bbytk80000gn/T/ipykernel_27883/3880632938.py:13: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   poi['centroid'] = poi['geometry'].centroid
# Isochrones calculated for POI 0
# Unable to build an isochrone map for POI. Skipping...
# Isochrones calculated for POI 2
# Isochrones calculated for POI 3
# Isochrones calculated for POI 4
# Isochrones calculated for POI 5
# Isochrones calculated for POI 6
# Isochrones calculated for POI 7
# Isochrones calculated for POI 8
# Isochrones calculated for POI 9
# Isochrones calculated for POI 10
# Isochrones calculated for POI 11
# Isochrones calculated for POI 12
# Isochrones calculated for POI 13
# Isochrones calculated for POI 14
# Isochrones calculated for POI 15
# Isochrones calculated for POI 16
# Isochrones calculated for POI 17
# Isochrones calculated for POI 18
# ...

# %% [markdown]
# ### Public spaces

# %%
input_file = '../data/output/wheelchair_publicspaces.geojson'
output_path = '../data/output/barcelona_isochrones_foot_public_spaces/'
output_filename = 'b_iso_foot_ps'
print_statement = "Isochrones calculated for POI {}"

calculate_isochrones_walk(input_file, output_path, output_filename, print_statement, profile)

# %%
# Das sind sehr viele, sicher?
'''input_file = '../data/output/null_wheelchair_publicspaces.geojson'
output_path = '../data/output/barcelona_isochrones_bike_greenspaces/'
output_filename = 'b_iso_foot_ps_null'
print_statement = "Isochrones calculated for POI {}"

calculate_isochrones_walk(input_file, output_path, output_filename, print_statement, profile)'''

# %% [markdown]
# # Plot isochrones

# %%
import matplotlib.pyplot as plt

def plot_isochrones(isochrone_directory, poi_data, title=None, blue_opacity=0.3, green_opacity=0.3, label_centroid='',save_directory=None):
    
    # Initialize the plot
    fig, ax = plt.subplots(figsize=(10, 10))

    # Iterate over each isochrone file
    for filename in os.listdir(isochrone_directory):
        if filename.endswith('.geojson'):
            # Load isochrone data, but ignore the 'center' column
            isochrone_data = gpd.read_file(os.path.join(isochrone_directory, filename), ignore_fields=['center'])

            # Create a GeoDataFrame for plotting
            plot_data = gpd.GeoDataFrame(geometry=isochrone_data['geometry'], crs=isochrone_data.crs)
            plot_data['value'] = isochrone_data['value']  # Add the 'value' column

            # Iterate over each row in the isochrone data
            for idx, row in plot_data.iterrows():
                value = row['value']  # Get the value from the current row
                color = 'blue' if value == 900 else 'green' if value == 1800 else None  # Assign color based on value
                if color:
                    alpha = blue_opacity if color == 'blue' else green_opacity  # Set opacity
                    plot_data.loc[idx:idx].plot(ax=ax, color=color, alpha=alpha)  # Plot the geometry with the assigned color

    # Plot the points of interest
    poi_data.plot(ax=ax, color='red', markersize=50, alpha=0.7, label=label_centroid)

    # Add legend
    blue_patch = plt.Line2D([0], [0], marker='o', color='w', markerfacecolor='green', markersize=10, label='15 Minutes')
    green_patch = plt.Line2D([0], [0], marker='o', color='w', markerfacecolor='blue', markersize=10, label='30 Minutes')
    red_patch = plt.Line2D([0], [0], marker='o', color='w', markerfacecolor='red', markersize=10, label=label_centroid)
    ax.legend(handles=[blue_patch, green_patch, red_patch])

    # Set title
    if title:
        ax.set_title(title)

    # Save the plot
    if save_directory:
        save_filename = os.path.join(save_directory, f"{title.replace(' ', '_')}.png")
        plt.savefig(save_filename)

    # Show the plot
    plt.show()

# %%
# Specify the path to the isochrone directory and points of interest GeoJSON file
isochrone_directory = '../data/output/barcelona_isochrones_bike_greenspaces/'
poi_file_path = '../data/output/greenspaces.geojson'

# Load points of interest data
poi_data = gpd.read_file(poi_file_path)

# Specify the title and label for the plot
title = 'Isochrones for Walking Profile'
label_centroid = 'Green Spaces'

# Specify the directory where you want to save the plot
save_directory = '../plots/'

# Plot the isochrones and points of interest
plot_isochrones(isochrone_directory, poi_data, title=title, label_centroid=label_centroid, save_directory=save_directory)

# %%
# Isochrones Walking Barcelona
isochrone_directory = '../data/output/barcelona_isochrones_bike_greenspaces/'
poi_data = gpd.read_file('../data/output/greenspaces.geojson')
save_path = '../plots/'
label_centroid= "Green Spaces"

plot_isochrones(isochrone_directory, poi_data, title='Isochrones for Walking Profile', label_centroid=label_centroid,save_directory='../plots/')
# Out:
# ---------------------------------------------------------------------------
# DriverError                               Traceback (most recent call last)
# Cell In[95], line 7
#       4 save_path = '../plots/'
#       5 label_centroid= "Green Spaces"
# ----> 7 plot_isochrones(isochrone_directory, poi_data, title='Isochrones for Walking Profile', label_centroid=label_centroid,save_directory='../plots/')
#
# Cell In[94], line 12, in plot_isochrones(isochrone_directory, poi_data, title, blue_opacity, green_opacity, label_centroid, save_directory)
#       9 for filename in os.listdir(isochrone_directory):
#      10     if filename.endswith('.geojson'):
#      11         # Load isochrone data, but ignore the 'center' column
# ---> 12         isochrone_data = gpd.read_file(os.path.join(isochrone_directory, filename), ignore_fields=['center'])
#      14         # Create a GeoDataFrame for plotting
# ...

# %% [markdown]
# # Merging isochrones?

# %%
import os
import geopandas as gpd
import pandas as pd

# Directory containing the isochrone GeoJSON files
isochrone_directory = '../data/output/barcelona_isochrones_foot_greenspaces/'

# Initialize an empty GeoDataFrame to store merged isochrones
merged_isochrones = gpd.GeoDataFrame()

# Iterate over each isochrone file
for filename in os.listdir(isochrone_directory):
    if filename.endswith('.geojson'):
        # Load isochrone data
        isochrone_data = gpd.read_file(os.path.join(isochrone_directory, filename))
        
        # Merge isochrones with the same value
        merged_isochrones = pd.concat([merged_isochrones, isochrone_data])

# Merge or dissolve the isochrones based on their common attribute (e.g., 'value')
# Example for dissolving based on 'value':
# merged_isochrones = merged_isochrones.dissolve(by='value')

# Save the merged isochrones to a new GeoJSON file
merged_isochrones.to_file('../data/output/barcelona_merged_isochrones_bike.geojson', driver='GeoJSON')
# Out:
# 2024-04-13 10:16:50,592  collection  WARNING:  Skipping field center: invalid type 3
# 2024-04-13 10:16:50,640  collection  WARNING:  Skipping field center: invalid type 3
# 2024-04-13 10:16:50,649  collection  WARNING:  Skipping field center: invalid type 3
# 2024-04-13 10:16:50,654  collection  WARNING:  Skipping field center: invalid type 3
# 2024-04-13 10:16:50,675  collection  WARNING:  Skipping field center: invalid type 3
# 2024-04-13 10:16:50,682  collection  WARNING:  Skipping field center: invalid type 3
# 2024-04-13 10:16:50,687  collection  WARNING:  Skipping field center: invalid type 3
# 2024-04-13 10:16:50,697  collection  WARNING:  Skipping field center: invalid type 3
# 2024-04-13 10:16:50,702  collection  WARNING:  Skipping field center: invalid type 3
# 2024-04-13 10:16:50,706  collection  WARNING:  Skipping field center: invalid type 3
# 2024-04-13 10:16:50,711  collection  WARNING:  Skipping field center: invalid type 3
# ...

# %%
import os
import geopandas as gpd

# Directory containing the isochrone GeoJSON files
isochrone_directory = '../data/output/barcelona_isochrones_bike/'

# Initialize an empty GeoDataFrame to store merged isochrones
merged_isochrones = gpd.GeoDataFrame()

# Iterate over each isochrone file
for filename in os.listdir(isochrone_directory):
    if filename.endswith('.geojson'):
        # Load isochrone data
        isochrone_data = gpd.read_file(os.path.join(isochrone_directory, filename))
        
        # Merge isochrones with the same value
        merged_isochrones = gpd.GeoDataFrame(pd.concat([merged_isochrones, isochrone_data], ignore_index=True))

# Dissolve the merged isochrones based on the 'value' attribute
dissolved_isochrones = merged_isochrones.dissolve(by='value')

# Save the dissolved isochrones to a new GeoJSON file
dissolved_isochrones.to_file('../data/output/barcelona_dissolved_isochrones_bike.geojson', driver='GeoJSON')
# Out:
# 2024-04-10 20:22:48,947  collection  WARNING:  Skipping field center: invalid type 3
# 2024-04-10 20:22:48,952  geodataframe  WARNING:  Several features with id = 2 have been found. Altering it to be unique. This warning will not be emitted anymore for this layer
# 2024-04-10 20:22:48,998  collection  WARNING:  Skipping field center: invalid type 3
# 2024-04-10 20:22:48,998  geodataframe  WARNING:  Several features with id = 23 have been found. Altering it to be unique. This warning will not be emitted anymore for this layer
# 2024-04-10 20:22:49,020  collection  WARNING:  Skipping field center: invalid type 3
# 2024-04-10 20:22:49,020  geodataframe  WARNING:  Several features with id = 15 have been found. Altering it to be unique. This warning will not be emitted anymore for this layer
# 2024-04-10 20:22:49,028  collection  WARNING:  Skipping field center: invalid type 3
# ...

# %%
import matplotlib.pyplot as plt

def plot_isochrones_with_opacity(isochrone_directory, poi_data, title=None, blue_opacity=0.3, green_opacity=0.3, label_centroid='',save_directory=None):

    # Initialize the plot
    fig, ax = plt.subplots(figsize=(10, 10))

    # Iterate over each isochrone file
    for filename in os.listdir(isochrone_directory):
        if filename.endswith('.geojson'):
            # Load isochrone data
            isochrone_data = gpd.read_file(os.path.join(isochrone_directory, filename))

            # Create a GeoDataFrame for plotting
            plot_data = gpd.GeoDataFrame(geometry=isochrone_data['geometry'], crs=isochrone_data.crs)
            plot_data['value'] = isochrone_data['value']  # Add the 'value' column

            # Iterate over each row in the isochrone data
            for idx, row in plot_data.iterrows():
                value = row['value']  # Get the value from the current row
                color = 'blue' if value == 900 else 'green' if value == 1800 else None  # Assign color based on value
                if color:
                    alpha = blue_opacity if color == 'blue' else green_opacity  # Set opacity
                    plot_data.loc[idx:idx].plot(ax=ax, color=color, alpha=alpha)  # Plot the geometry with the assigned color

    # Plot the points of interest
    poi_data.plot(ax=ax, color='red', markersize=50, alpha=0.7, label=label_centroid)

    # Add legend
    blue_patch = plt.Line2D([0], [0], marker='o', color='w', markerfacecolor='blue', markersize=10, label='15 Minutes')
    green_patch = plt.Line2D([0], [0], marker='o', color='w', markerfacecolor='green', markersize=10, label='30 Minutes')
    red_patch = plt.Line2D([0], [0], marker='o', color='w', markerfacecolor='red', markersize=10, label=label_centroid)
    ax.legend(handles=[blue_patch, green_patch, red_patch])

    # Set title
    if title:
        ax.set_title(title)

    # Save the plot
    if save_directory:
        save_filename = os.path.join(save_directory, f"{title.replace(' ', '_')}.png")
        plt.savefig(save_filename)

    # Show the plot
    plt.show()
    
# Isochrones Walking Barcelona
isochrone_directory = '../data/output/3iso_bike/'
poi_data = gpd.read_file('../data/output/wheelchair_public_building.geojson')
save_path = '../plots/'
label_centroid= "Public Building"

plot_isochrones_with_opacity(isochrone_directory, poi_data, title='Isochrones for Biking Profile', label_centroid=label_centroid,save_directory='../plots/')

# %% [markdown]
# # ursprung

# %%
import os
import geopandas as gpd
import matplotlib.pyplot as plt

def plot_isochrones_with_opacity(isochrone_directory, poi_data, blue_opacity=0.6, green_opacity=0.5):
    """
    Plot isochrones from GeoJSON files with customizable opacity.

    Parameters:
        isochrone_directory (str): Directory containing the isochrone GeoJSON files.
        poi_data (GeoDataFrame): Points of interest data.
        blue_opacity (float): Opacity (alpha value) for blue isochrones.
        green_opacity (float): Opacity (alpha value) for green isochrones.
    """
    # Initialize the plot
    fig, ax = plt.subplots(figsize=(10, 10))

    # Iterate over each isochrone file
    for filename in os.listdir(isochrone_directory):
        if filename.endswith('.geojson'):
            # Load isochrone data
            isochrone_data = gpd.read_file(os.path.join(isochrone_directory, filename))
            
            # Create a GeoDataFrame for plotting
            plot_data = gpd.GeoDataFrame(geometry=isochrone_data['geometry'], crs=isochrone_data.crs)
            plot_data['value'] = isochrone_data['value']  # Add the 'value' column
            
            # Iterate over each row in the isochrone data
            for idx, row in plot_data.iterrows():
                value = row['value']  # Get the value from the current row
                color = 'blue' if value == 900 else 'green' if value == 1800 else None  # Assign color based on value
                if color:
                    alpha = blue_opacity if color == 'blue' else green_opacity  # Set opacity based on color
                    plot_data.loc[idx:idx].plot(ax=ax, color=color, alpha=alpha)  # Plot the geometry with the assigned color

    # Plot the points of interest
    poi_data.plot(ax=ax, color='red', markersize=50, alpha=0.7, label='POI Centroids')

    # Add legend
    blue_patch = plt.Line2D([0], [0], marker='o', color='w', markerfacecolor='blue', markersize=10, label='Isochrone 900')
    green_patch = plt.Line2D([0], [0], marker='o', color='w', markerfacecolor='green', markersize=10, label='Isochrone 1800')
    red_patch = plt.Line2D([0], [0], marker='o', color='w', markerfacecolor='red', markersize=10, label='POI Centroids')
    ax.legend(handles=[blue_patch, green_patch, red_patch])

    # Set title
    ax.set_title('Isochrones with Custom Opacity')

    # Show the plot
    plt.show()

# %%
# Example usage
isochrone_directory = '../data/output/barcelona_isochrones_bike/'
poi_data = gpd.read_file('../data/output/wheelchair_public_building.geojson')

# Call the function with the required arguments
plot_isochrones_with_opacity(isochrone_directory, poi_data, blue_opacity=0.6, green_opacity=0.5)
# Out:
# 2024-04-10 20:01:26,647  collection  WARNING:  Skipping field center: invalid type 3
# 2024-04-10 20:01:26,647  geodataframe  WARNING:  Several features with id = 2 have been found. Altering it to be unique. This warning will not be emitted anymore for this layer
# 2024-04-10 20:01:26,688  collection  WARNING:  Skipping field center: invalid type 3
# 2024-04-10 20:01:26,689  geodataframe  WARNING:  Several features with id = 23 have been found. Altering it to be unique. This warning will not be emitted anymore for this layer
# 2024-04-10 20:01:26,722  collection  WARNING:  Skipping field center: invalid type 3
# 2024-04-10 20:01:26,723  geodataframe  WARNING:  Several features with id = 15 have been found. Altering it to be unique. This warning will not be emitted anymore for this layer
# 2024-04-10 20:01:26,761  collection  WARNING:  Skipping field center: invalid type 3
# ...
