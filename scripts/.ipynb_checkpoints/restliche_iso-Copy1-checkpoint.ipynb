# %%
import json
import time
import os
import geopandas as gpd
from openrouteservice import Client
from openrouteservice.exceptions import ApiError

def calculate_isochrones_bike(input_file, output_path, output_filename, print_statement, resume_index=None):
    # Load poi data with GeoPandas
    poi = gpd.read_file(input_file)

    # Calculate centroids for each polygon
    poi['centroid'] = poi['geometry'].centroid

    # Change CRS to EPSG:4326
    poi = poi.to_crs("EPSG:4326")

    # Get the name of the ID column
    poi_id_column = 'id'  # Assuming the column name is 'id'

    # Initialize OpenRouteService client
    api_key = "5b3ce3597851110001cf6248f4b15fecc73f408fb335b759eb0be4b6"  # Replace with your actual API key
    client = Client(key=api_key)

    # Define parameters for isochrone calculation
    profile = 'cycling-regular'
    range_type = 'time'
    range_seconds = [900, 1800]  # 15 and 30 Minutes

    # Create the directory if it doesn't exist
    os.makedirs(output_path, exist_ok=True)

    # Function to calculate isochrones with retry mechanism
    def calculate_isochrones_with_retry(coordinate):
        retries = 3  # Number of retries
        for attempt in range(retries):
            try:
                isochrones = client.isochrones(locations=[coordinate], profile=profile, range_type=range_type, range=range_seconds, attributes=['total_pop'])
                return isochrones
            except ApiError as e:
                if "rate limit exceeded" in str(e):
                    print(f"Rate limit exceeded. Retrying in 10 seconds...")
                    time.sleep(10)  # Retry after 10 seconds for rate limit errors
                elif "Unable to build an isochrone map" in str(e):
                    print(f"Unable to build an isochrone map for POI. Skipping...")
                    return None
                else:
                    raise e  # Re-raise the exception if it's not related to rate limit exceeded
        return None

    # Iterate over poi and calculate isochrones
    for idx, row in poi.iterrows():
        # Skip POIs before the resume index
        if resume_index is not None and idx < resume_index:
            continue

        # Get centroid coordinates of the poi
        lon, lat = row['centroid'].x, row['centroid'].y
        coordinate = (lon, lat)

        # Calculate isochrones with retry mechanism
        isochrones = calculate_isochrones_with_retry(coordinate)
        if isochrones is None:
            continue  # Skip the poi if isochrones cannot be calculated
            
        # Get the poi ID from the column
        poi_id = row[poi_id_column]

        # Add poi ID to each isochrone feature
        for feature in isochrones['features']:
            feature['properties']['poi_id'] = poi_id

        # Save isochrones data to file
        output_file_path = os.path.join(output_path, f'{output_filename}_{idx + 1}.geojson')
        
        with open(output_file_path, 'w') as output_file:
            json.dump(isochrones, output_file)

        print(print_statement.format(idx))

        # Rate limit handling
        time.sleep(3)  # Add a small delay to avoid rate limits and respect the rate limit

    print("Isochrone calculation completed.")

# %%
import json
import time
import os
import geopandas as gpd
from openrouteservice import Client
from openrouteservice.exceptions import ApiError

def calculate_isochrones_walk(input_file, output_path, output_filename, print_statement, resume_index=None):
    # Load poi data with GeoPandas
    poi = gpd.read_file(input_file)

    # Calculate centroids for each polygon
    poi['centroid'] = poi['geometry'].centroid

    # Change CRS to EPSG:4326
    poi = poi.to_crs("EPSG:4326")

    # Get the name of the ID column
    poi_id_column = 'id'  # Assuming the column name is 'id'

    # Initialize OpenRouteService client
    api_key = "5b3ce3597851110001cf624894b952965f634566ae09a8aa3c5da23c"  # Replace with your actual API key
    client = Client(key=api_key)

    # Define parameters for isochrone calculation
    profile = 'foot-walking'
    range_type = 'time'
    range_seconds = [900, 1800]  # 15 and 30 Minutes

    # Create the directory if it doesn't exist
    os.makedirs(output_path, exist_ok=True)

    # Function to calculate isochrones with retry mechanism
    def calculate_isochrones_with_retry(coordinate):
        retries = 3  # Number of retries
        for attempt in range(retries):
            try:
                isochrones = client.isochrones(locations=[coordinate], profile=profile, range_type=range_type, range=range_seconds, attributes=['total_pop'])
                return isochrones
            except ApiError as e:
                if "rate limit exceeded" in str(e):
                    print(f"Rate limit exceeded. Retrying in 10 seconds...")
                    time.sleep(10)  # Retry after 10 seconds for rate limit errors
                elif "Unable to build an isochrone map" in str(e):
                    print(f"Unable to build an isochrone map for POI. Skipping...")
                    return None
                else:
                    raise e  # Re-raise the exception if it's not related to rate limit exceeded
        return None

    # Iterate over poi and calculate isochrones
    for idx, row in poi.iterrows():
        # Skip POIs before the resume index
        if resume_index is not None and idx < resume_index:
            continue

        # Get centroid coordinates of the poi
        lon, lat = row['centroid'].x, row['centroid'].y
        coordinate = (lon, lat)

        # Calculate isochrones with retry mechanism
        isochrones = calculate_isochrones_with_retry(coordinate)
        if isochrones is None:
            continue  # Skip the poi if isochrones cannot be calculated
            
        # Get the poi ID from the column
        poi_id = row[poi_id_column]

        # Add poi ID to each isochrone feature
        for feature in isochrones['features']:
            feature['properties']['poi_id'] = poi_id

        # Save isochrones data to file
        output_file_path = os.path.join(output_path, f'{output_filename}_{idx + 1}.geojson')
        
        with open(output_file_path, 'w') as output_file:
            json.dump(isochrones, output_file)

        print(print_statement.format(idx))

        # Rate limit handling
        time.sleep(3)  # Add a small delay to avoid rate limits and respect the rate limit

    print("Isochrone calculation completed.")

# %%
input_file = '../data/output/munich/access/combined_public_building_wheelchair.geojson'
output_path = '../data/output/munich/isochrones_foot_public_building_wheelchair/'
output_filename = 'b_iso_foot_public_building_w'
print_statement = "Isochrones calculated for POI {}"

calculate_isochrones_walk(input_file, output_path, output_filename, print_statement, resume_index=97)
#done
# Out:
# /var/folders/_n/_djf18r57q3482fkc8bbytk80000gn/T/ipykernel_41776/1011180611.py:13: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   poi['centroid'] = poi['geometry'].centroid
# Isochrones calculated for POI 97
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[17], line 6
#       3 output_filename = 'b_iso_foot_public_building_w'
#       4 print_statement = "Isochrones calculated for POI {}"
# ----> 6 calculate_isochrones_walk(input_file, output_path, output_filename, print_statement, resume_index=97)
#
# Cell In[15], line 82, in calculate_isochrones_walk(input_file, output_path, output_filename, print_statement, resume_index)
#      79     print(print_statement.format(idx))
#      81     # Rate limit handling
# ---> 82     time.sleep(3)  # Add a small delay to avoid rate limits and respect the rate limit
#      84 print("Isochrone calculation completed.")
#
# KeyboardInterrupt:

# %%
input_file = '../data/output/munich/access/wheelchair_publicspaces.geojson'
output_path = '../data/output/munich/isochrones_bike_public_spaces_wheelchair/'
output_filename = 'b_iso_bike_public_spaces_w'
print_statement = "Isochrones calculated for POI {}"
calculate_isochrones_bike(input_file, output_path, output_filename, print_statement, resume_index=74)
## done
# Out:
# /var/folders/_n/_djf18r57q3482fkc8bbytk80000gn/T/ipykernel_41776/3833481283.py:13: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   poi['centroid'] = poi['geometry'].centroid
# Isochrones calculated for POI 74
# Isochrones calculated for POI 75
# Isochrones calculated for POI 76
# Isochrones calculated for POI 77
# Isochrones calculated for POI 78
# Isochrones calculated for POI 79
# Isochrones calculated for POI 80
# Isochrones calculated for POI 81
# Isochrones calculated for POI 82
# Isochrones calculated for POI 83
# Isochrones calculated for POI 84
# Isochrones calculated for POI 85
# Isochrones calculated for POI 86
# Isochrones calculated for POI 87
# Isochrones calculated for POI 88
# Isochrones calculated for POI 89
# Isochrones calculated for POI 90
# Isochrones calculated for POI 91
# Isochrones calculated for POI 92
# Isochrones calculated for POI 93
# Isochrones calculated for POI 94
# Isochrones calculated for POI 95
# Isochrones calculated for POI 96
# Isochrones calculated for POI 97
# Isochrones calculated for POI 98
# Isochrones calculated for POI 99
# Isochrones calculated for POI 100
# Isochrones calculated for POI 101
# Isochrones calculated for POI 102
# Isochrones calculated for POI 103
# Isochrones calculated for POI 104
# Isochrones calculated for POI 105
# Isochrones calculated for POI 106
# Isochrones calculated for POI 107
# Isochrones calculated for POI 108
# Isochrones calculated for POI 109
# Isochrones calculated for POI 110
# Isochrones calculated for POI 111
# Isochrones calculated for POI 112
# Isochrones calculated for POI 113
# Isochrones calculated for POI 114
# Isochrones calculated for POI 115
# Isochrones calculated for POI 116
# Isochrones calculated for POI 117
# Isochrones calculated for POI 118
# Isochrones calculated for POI 119
# Isochrones calculated for POI 120
# Isochrones calculated for POI 121
# Isochrones calculated for POI 122
# Isochrones calculated for POI 123
# Isochrones calculated for POI 124
# Isochrones calculated for POI 125
# Isochrones calculated for POI 126
# Isochrones calculated for POI 127
# Isochrones calculated for POI 128
# Isochrones calculated for POI 129
# Isochrones calculated for POI 130
# Isochrones calculated for POI 131
# Isochrones calculated for POI 132
# Isochrones calculated for POI 133
# Isochrones calculated for POI 134
# Isochrones calculated for POI 135
# Isochrones calculated for POI 136
# Isochrones calculated for POI 137
# Isochrones calculated for POI 138
# Isochrones calculated for POI 139
# Isochrones calculated for POI 140
# Isochrones calculated for POI 141
# Isochrones calculated for POI 142
# Isochrones calculated for POI 143
# Isochrones calculated for POI 144
# Isochrones calculated for POI 145
# Isochrones calculated for POI 146
# Isochrones calculated for POI 147
# Isochrones calculated for POI 148
# Isochrones calculated for POI 149
# Isochrones calculated for POI 150
# Isochrones calculated for POI 151
# Isochrones calculated for POI 152
# Isochrones calculated for POI 153
# Isochrones calculated for POI 154
# Isochrones calculated for POI 155
# Isochrones calculated for POI 156
# Isochrones calculated for POI 157
# Isochrones calculated for POI 158
# Isochrones calculated for POI 159
# Isochrones calculated for POI 160
# Isochrones calculated for POI 161
# Isochrones calculated for POI 162
# Isochrones calculated for POI 163
# Isochrones calculated for POI 164
# Isochrones calculated for POI 165
# Isochrones calculated for POI 166
# Isochrones calculated for POI 167
# Isochrones calculated for POI 168
# Isochrones calculated for POI 169
# Isochrones calculated for POI 170
# Isochrones calculated for POI 171
# Isochrones calculated for POI 172
# Isochrones calculated for POI 173
# Isochrones calculated for POI 174
# Isochrones calculated for POI 175
# Isochrones calculated for POI 176
# Isochrones calculated for POI 177
# Isochrones calculated for POI 178
# Isochrones calculated for POI 179
# Isochrones calculated for POI 180
# Isochrones calculated for POI 181
# Isochrones calculated for POI 182
# Isochrones calculated for POI 183
# Isochrones calculated for POI 184
# Isochrones calculated for POI 185
# Isochrones calculated for POI 186
# Isochrones calculated for POI 187
# Isochrones calculated for POI 188
# Isochrones calculated for POI 189
# Isochrones calculated for POI 190
# Isochrones calculated for POI 191
# Isochrones calculated for POI 192
# Isochrones calculated for POI 193
# Isochrones calculated for POI 194
# Isochrones calculated for POI 195
# Isochrones calculated for POI 196
# Isochrones calculated for POI 197
# Isochrones calculated for POI 198
# Isochrones calculated for POI 199
# Isochrones calculated for POI 200
# Isochrones calculated for POI 201
# Isochrones calculated for POI 202
# Isochrones calculated for POI 203
# Isochrones calculated for POI 204
# Isochrones calculated for POI 205
# Isochrones calculated for POI 206
# Isochrones calculated for POI 207
# Isochrones calculated for POI 208
# Isochrones calculated for POI 209
# Isochrones calculated for POI 210
# Isochrones calculated for POI 211
# Isochrones calculated for POI 212
# Isochrones calculated for POI 213
# Isochrones calculated for POI 214
# Isochrones calculated for POI 215
# Isochrones calculated for POI 216
# Isochrones calculated for POI 217
# Isochrones calculated for POI 218
# Isochrones calculated for POI 219
# Isochrones calculated for POI 220
# Isochrones calculated for POI 221
# Isochrones calculated for POI 222
# Isochrones calculated for POI 223
# Isochrones calculated for POI 224
# Isochrones calculated for POI 225
# Isochrones calculated for POI 226
# Isochrones calculated for POI 227
# Isochrones calculated for POI 228
# Isochrones calculated for POI 229
# Isochrones calculated for POI 230
# Isochrones calculated for POI 231
# Isochrones calculated for POI 232
# Isochrones calculated for POI 233
# Isochrones calculated for POI 234
# Isochrones calculated for POI 235
# Isochrones calculated for POI 236
# Isochrones calculated for POI 237
# Isochrones calculated for POI 238
# Isochrones calculated for POI 239
# Isochrones calculated for POI 240
# Isochrones calculated for POI 241
# Isochrones calculated for POI 242
# Isochrones calculated for POI 243
# Isochrones calculated for POI 244
# Isochrones calculated for POI 245
# Isochrones calculated for POI 246
# Isochrones calculated for POI 247
# Isochrones calculated for POI 248
# Isochrones calculated for POI 249
# Isochrones calculated for POI 250
# Isochrones calculated for POI 251
# Isochrones calculated for POI 252
# Isochrones calculated for POI 253
# Isochrones calculated for POI 254
# Isochrones calculated for POI 255
# Isochrones calculated for POI 256
# Isochrones calculated for POI 257
# Isochrones calculated for POI 258
# Isochrones calculated for POI 259
# Isochrones calculated for POI 260
# Isochrones calculated for POI 261
# Isochrones calculated for POI 262
# Isochrones calculated for POI 263
# Isochrones calculated for POI 264
# Isochrones calculated for POI 265
# Isochrones calculated for POI 266
# Isochrones calculated for POI 267
# Isochrones calculated for POI 268
# Unable to build an isochrone map for POI. Skipping...
# Isochrones calculated for POI 270
# Isochrones calculated for POI 271
# Isochrones calculated for POI 272
# Isochrones calculated for POI 273
# Isochrones calculated for POI 274
# Isochrones calculated for POI 275
# Unable to build an isochrone map for POI. Skipping...
# Isochrones calculated for POI 277
# Isochrones calculated for POI 278
# Isochrones calculated for POI 279
# Isochrones calculated for POI 280
# Isochrones calculated for POI 281
# Isochrones calculated for POI 282
# Isochrones calculated for POI 283
# Isochrones calculated for POI 284
# Isochrones calculated for POI 285
# Isochrones calculated for POI 286
# Isochrones calculated for POI 287
# Isochrones calculated for POI 288
# Isochrones calculated for POI 289
# Isochrones calculated for POI 290
# Isochrones calculated for POI 291
# Isochrones calculated for POI 292
# Isochrones calculated for POI 293
# Isochrones calculated for POI 294
# Isochrones calculated for POI 295
# Isochrones calculated for POI 296
# Isochrones calculated for POI 297
# Unable to build an isochrone map for POI. Skipping...
# Isochrones calculated for POI 299
# Isochrones calculated for POI 300
# Isochrones calculated for POI 301
# Isochrones calculated for POI 302
# Unable to build an isochrone map for POI. Skipping...
# Isochrones calculated for POI 304
# Isochrones calculated for POI 305
# Isochrones calculated for POI 306
# Isochrones calculated for POI 307
# Isochrones calculated for POI 308
# Isochrones calculated for POI 309
# Isochrones calculated for POI 310
# Isochrones calculated for POI 311
# Isochrones calculated for POI 312
# Isochrones calculated for POI 313
# Isochrones calculated for POI 314
# Isochrones calculated for POI 315
# Isochrones calculated for POI 316
# Isochrones calculated for POI 317
# Isochrones calculated for POI 318
# Isochrones calculated for POI 319
# Isochrones calculated for POI 320
# Isochrones calculated for POI 321
# Isochrones calculated for POI 322
# Isochrones calculated for POI 323
# Isochrones calculated for POI 324
# Isochrones calculated for POI 325
# Isochrones calculated for POI 326
# Isochrones calculated for POI 327
# Isochrones calculated for POI 328
# Isochrones calculated for POI 329
# Isochrones calculated for POI 330
# Isochrones calculated for POI 331
# Isochrones calculated for POI 332
# Isochrones calculated for POI 333
# Isochrones calculated for POI 334
# Isochrones calculated for POI 335
# Isochrones calculated for POI 336
# Unable to build an isochrone map for POI. Skipping...
# Isochrones calculated for POI 338
# Unable to build an isochrone map for POI. Skipping...
# Isochrones calculated for POI 340
# Isochrones calculated for POI 341
# Isochrones calculated for POI 342
# Isochrones calculated for POI 343
# Isochrones calculated for POI 344
# Isochrones calculated for POI 345
# Isochrones calculated for POI 346
# Isochrones calculated for POI 347
# Isochrones calculated for POI 348
# Isochrones calculated for POI 349
# Isochrones calculated for POI 350
# Isochrones calculated for POI 351
# Isochrones calculated for POI 352
# Isochrones calculated for POI 353
# Isochrone calculation completed.

# %%
input_file = '../data/output/barcelona/access/combined_public_building_wheelchair.geojson'
output_path = '../data/output/barcelona/isochrones_bike_public_building/'
output_filename = 'b_iso_bike_public_building'
print_statement = "Isochrones calculated for POI {}"

calculate_isochrones_bike(input_file, output_path, output_filename, print_statement, resume_index=722)

#done
# Out:
# /var/folders/_n/_djf18r57q3482fkc8bbytk80000gn/T/ipykernel_41776/1757517212.py:13: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   poi['centroid'] = poi['geometry'].centroid
# Isochrones calculated for POI 722
# Isochrones calculated for POI 723
# Isochrones calculated for POI 724
# Isochrones calculated for POI 725
# Isochrones calculated for POI 726
# Isochrones calculated for POI 727
# Isochrones calculated for POI 728
# Isochrones calculated for POI 729
# Isochrones calculated for POI 730
# Unable to build an isochrone map for POI. Skipping...
# Isochrones calculated for POI 732
# Isochrones calculated for POI 733
# Isochrones calculated for POI 734
# Isochrones calculated for POI 735
# Isochrones calculated for POI 736
# Isochrones calculated for POI 737
# Isochrones calculated for POI 738
# Isochrones calculated for POI 739
# Isochrones calculated for POI 740
# Isochrones calculated for POI 741
# Isochrones calculated for POI 742
# Isochrones calculated for POI 743
# Isochrones calculated for POI 744
# Isochrones calculated for POI 745
# Isochrones calculated for POI 746
# Isochrones calculated for POI 747
# Isochrones calculated for POI 748
# Isochrones calculated for POI 749
# Isochrones calculated for POI 750
# Isochrones calculated for POI 751
# Isochrones calculated for POI 752
# Isochrones calculated for POI 753
# Isochrones calculated for POI 754
# Isochrones calculated for POI 755
# Isochrones calculated for POI 756
# Isochrones calculated for POI 757
# Isochrones calculated for POI 758
# Isochrones calculated for POI 759
# Isochrones calculated for POI 760
# Isochrones calculated for POI 761
# Isochrones calculated for POI 762
# Isochrones calculated for POI 763
# Isochrones calculated for POI 764
# Isochrones calculated for POI 765
# Isochrones calculated for POI 766
# Isochrones calculated for POI 767
# Isochrones calculated for POI 768
# Isochrones calculated for POI 769
# Isochrones calculated for POI 770
# Isochrones calculated for POI 771
# Isochrones calculated for POI 772
# Isochrones calculated for POI 773
# Isochrones calculated for POI 774
# Isochrones calculated for POI 775
# Isochrones calculated for POI 776
# Isochrones calculated for POI 777
# Isochrones calculated for POI 778
# /Users/celinathome/anaconda3/lib/python3.11/site-packages/openrouteservice/client.py:211: UserWarning: Rate limit exceeded. Retrying for the 1st time.
#   warnings.warn('Rate limit exceeded. Retrying for the {0}{1} time.'.format(retry_counter + 1,
# /Users/celinathome/anaconda3/lib/python3.11/site-packages/openrouteservice/client.py:211: UserWarning: Rate limit exceeded. Retrying for the 2nd time.
#   warnings.warn('Rate limit exceeded. Retrying for the {0}{1} time.'.format(retry_counter + 1,
# /Users/celinathome/anaconda3/lib/python3.11/site-packages/openrouteservice/client.py:211: UserWarning: Rate limit exceeded. Retrying for the 3rd time.
#   warnings.warn('Rate limit exceeded. Retrying for the {0}{1} time.'.format(retry_counter + 1,
# /Users/celinathome/anaconda3/lib/python3.11/site-packages/openrouteservice/client.py:211: UserWarning: Rate limit exceeded. Retrying for the 4th time.
#   warnings.warn('Rate limit exceeded. Retrying for the {0}{1} time.'.format(retry_counter + 1,
# /Users/celinathome/anaconda3/lib/python3.11/site-packages/openrouteservice/client.py:211: UserWarning: Rate limit exceeded. Retrying for the 5th time.
#   warnings.warn('Rate limit exceeded. Retrying for the {0}{1} time.'.format(retry_counter + 1,
# /Users/celinathome/anaconda3/lib/python3.11/site-packages/openrouteservice/client.py:211: UserWarning: Rate limit exceeded. Retrying for the 6th time.
#   warnings.warn('Rate limit exceeded. Retrying for the {0}{1} time.'.format(retry_counter + 1,
# /Users/celinathome/anaconda3/lib/python3.11/site-packages/openrouteservice/client.py:211: UserWarning: Rate limit exceeded. Retrying for the 7th time.
#   warnings.warn('Rate limit exceeded. Retrying for the {0}{1} time.'.format(retry_counter + 1,
# /Users/celinathome/anaconda3/lib/python3.11/site-packages/openrouteservice/client.py:211: UserWarning: Rate limit exceeded. Retrying for the 8th time.
#   warnings.warn('Rate limit exceeded. Retrying for the {0}{1} time.'.format(retry_counter + 1,
# Isochrones calculated for POI 779
# Isochrones calculated for POI 780
# Isochrones calculated for POI 781
# Isochrones calculated for POI 782
# Isochrones calculated for POI 783
# Isochrones calculated for POI 784
# Isochrones calculated for POI 785
# Isochrones calculated for POI 786
# Isochrones calculated for POI 787
# Isochrones calculated for POI 788
# Isochrones calculated for POI 789
# Isochrones calculated for POI 790
# Isochrones calculated for POI 791
# Isochrones calculated for POI 792
# Isochrones calculated for POI 793
# Isochrones calculated for POI 794
# Isochrones calculated for POI 795
# Isochrones calculated for POI 796
# Isochrones calculated for POI 797
# Isochrones calculated for POI 798
# Isochrones calculated for POI 799
# Isochrones calculated for POI 800
# Isochrones calculated for POI 801
# Isochrones calculated for POI 802
# Isochrones calculated for POI 803
# Isochrones calculated for POI 804
# Isochrones calculated for POI 805
# Isochrones calculated for POI 806
# Isochrones calculated for POI 807
# Isochrones calculated for POI 808
# Isochrones calculated for POI 809
# Isochrones calculated for POI 810
# Isochrones calculated for POI 811
# Isochrones calculated for POI 812
# Isochrones calculated for POI 813
# Isochrones calculated for POI 814
# Isochrones calculated for POI 815
# Isochrones calculated for POI 816
# Isochrones calculated for POI 817
# Isochrones calculated for POI 818
# Isochrones calculated for POI 819
# Isochrones calculated for POI 820
# Isochrones calculated for POI 821
# Isochrones calculated for POI 822
# Isochrones calculated for POI 823
# Isochrones calculated for POI 824
# Isochrones calculated for POI 825
# Isochrones calculated for POI 826
# Isochrones calculated for POI 827
# Isochrones calculated for POI 828
# Isochrones calculated for POI 829
# Isochrones calculated for POI 830
# Isochrones calculated for POI 831
# Isochrones calculated for POI 832
# Isochrones calculated for POI 833
# Isochrones calculated for POI 834
# Isochrones calculated for POI 835
# Isochrones calculated for POI 836
# Isochrones calculated for POI 837
# Isochrones calculated for POI 838
# Isochrones calculated for POI 839
# Isochrones calculated for POI 840
# Isochrones calculated for POI 841
# Isochrones calculated for POI 842
# Isochrones calculated for POI 843
# Isochrones calculated for POI 844
# Isochrones calculated for POI 845
# Isochrones calculated for POI 846
# Isochrones calculated for POI 847
# Isochrones calculated for POI 848
# Isochrones calculated for POI 849
# Isochrones calculated for POI 850
# Isochrones calculated for POI 851
# Isochrones calculated for POI 852
# Isochrones calculated for POI 853
# Isochrones calculated for POI 854
# Isochrones calculated for POI 855
# Isochrones calculated for POI 856
# Isochrones calculated for POI 857
# Isochrones calculated for POI 858
# Isochrones calculated for POI 859
# Isochrones calculated for POI 860
# Isochrones calculated for POI 861
# Isochrones calculated for POI 862
# Isochrones calculated for POI 863
# Isochrones calculated for POI 864
# Isochrones calculated for POI 865
# Isochrones calculated for POI 866
# Isochrones calculated for POI 867
# Isochrones calculated for POI 868
# Isochrones calculated for POI 869
# Isochrones calculated for POI 870
# Isochrones calculated for POI 871
# Isochrones calculated for POI 872
# Isochrones calculated for POI 873
# Isochrones calculated for POI 874
# Isochrones calculated for POI 875
# Isochrones calculated for POI 876
# Isochrones calculated for POI 877
# Isochrones calculated for POI 878
# Isochrones calculated for POI 879
# Isochrones calculated for POI 880
# Isochrones calculated for POI 881
# Isochrones calculated for POI 882
# Isochrones calculated for POI 883
# Isochrones calculated for POI 884
# Isochrones calculated for POI 885
# Isochrones calculated for POI 886
# Isochrones calculated for POI 887
# Isochrones calculated for POI 888
# Isochrones calculated for POI 889
# Isochrones calculated for POI 890
# Isochrones calculated for POI 891
# Isochrones calculated for POI 892
# Isochrones calculated for POI 893
# Isochrones calculated for POI 894
# Isochrones calculated for POI 895
# Isochrones calculated for POI 896
# Isochrones calculated for POI 897
# Isochrones calculated for POI 898
# Isochrones calculated for POI 899
# Isochrones calculated for POI 900
# Isochrones calculated for POI 901
# Isochrones calculated for POI 902
# Isochrones calculated for POI 903
# Isochrones calculated for POI 904
# Isochrones calculated for POI 905
# Isochrones calculated for POI 906
# Isochrones calculated for POI 907
# Isochrones calculated for POI 908
# Isochrones calculated for POI 909
# Isochrones calculated for POI 910
# Isochrones calculated for POI 911
# Isochrones calculated for POI 912
# Isochrones calculated for POI 913
# Isochrones calculated for POI 914
# Isochrones calculated for POI 915
# Isochrones calculated for POI 916
# Isochrones calculated for POI 917
# Isochrones calculated for POI 918
# Isochrones calculated for POI 919
# Isochrones calculated for POI 920
# Isochrones calculated for POI 921
# Isochrones calculated for POI 922
# Isochrones calculated for POI 923
# Isochrones calculated for POI 924
# Isochrones calculated for POI 925
# Isochrones calculated for POI 926
# Isochrones calculated for POI 927
# Isochrones calculated for POI 928
# Unable to build an isochrone map for POI. Skipping...
# Isochrones calculated for POI 930
# Isochrones calculated for POI 931
# Isochrones calculated for POI 932
# Isochrones calculated for POI 933
# Isochrones calculated for POI 934
# Isochrones calculated for POI 935
# Isochrones calculated for POI 936
# Isochrones calculated for POI 937
# Isochrones calculated for POI 938
# Isochrones calculated for POI 939
# Isochrones calculated for POI 940
# Isochrones calculated for POI 941
# Isochrones calculated for POI 942
# Isochrones calculated for POI 943
# Isochrones calculated for POI 944
# Isochrones calculated for POI 945
# Isochrones calculated for POI 946
# Isochrones calculated for POI 947
# Isochrones calculated for POI 948
# Isochrones calculated for POI 949
# Isochrones calculated for POI 950
# Isochrones calculated for POI 951
# Isochrones calculated for POI 952
# Isochrones calculated for POI 953
# Isochrones calculated for POI 954
# Isochrones calculated for POI 955
# Isochrones calculated for POI 956
# Isochrones calculated for POI 957
# Isochrones calculated for POI 958
# Isochrones calculated for POI 959
# Isochrones calculated for POI 960
# Isochrones calculated for POI 961
# Isochrones calculated for POI 962
# Isochrones calculated for POI 963
# Isochrones calculated for POI 964
# Isochrones calculated for POI 965
# Isochrones calculated for POI 966
# Isochrones calculated for POI 967
# Isochrones calculated for POI 968
# Isochrones calculated for POI 969
# Isochrones calculated for POI 970
# Isochrones calculated for POI 971
# Isochrones calculated for POI 972
# Isochrones calculated for POI 973
# Isochrones calculated for POI 974
# Isochrones calculated for POI 975
# Isochrones calculated for POI 976
# Isochrones calculated for POI 977
# Isochrones calculated for POI 978
# Isochrones calculated for POI 979
# Isochrones calculated for POI 980
# Isochrones calculated for POI 981
# Isochrones calculated for POI 982
# Isochrones calculated for POI 983
# Isochrones calculated for POI 984
# Isochrones calculated for POI 985
# Isochrones calculated for POI 986
# Isochrones calculated for POI 987
# Isochrones calculated for POI 988
# Isochrones calculated for POI 989
# Isochrones calculated for POI 990
# Isochrones calculated for POI 991
# Isochrones calculated for POI 992
# Isochrones calculated for POI 993
# Isochrones calculated for POI 994
# Isochrones calculated for POI 995
# Isochrones calculated for POI 996
# Isochrones calculated for POI 997
# Isochrones calculated for POI 998
# Isochrones calculated for POI 999
# Isochrones calculated for POI 1000
# Isochrones calculated for POI 1001
# Isochrones calculated for POI 1002
# Isochrones calculated for POI 1003
# Isochrone calculation completed.

# %%
# done, in untitled

input_file = '../data/output/barcelona/access/combined_public_building_wheelchair.geojson'
output_path = '../data/output/barcelona/isochrones_foot_public_building_wheelchair/'
output_filename = 'b_iso_foot_public_building_w'
print_statement = "Isochrones calculated for POI {}"

calculate_isochrones_walk(input_file, output_path, output_filename, print_statement, resume_index=2)

# %%
## still due, 565/2507, in Untitled2

input_file = '../data/output/barcelona/access/combined_public_spaces_wheelchair.geojson'
output_path = '../data/output/barcelona/isochrones_bike_greenspaces_wheelchair/'
output_filename = 'b_iso_bike_greenspaces_w'
print_statement = "Isochrones calculated for POI {}"
calculate_isochrones_bike(input_file, output_path, output_filename, print_statement, resume_index=565)

# %%
## still due, 377/3709, in untitled1

input_file = '../data/output/munich/access/combined_public_spaces_wheelchair.geojson'
output_path = '../data/output/munich/isochrones_foot_public_spaces/'
output_filename = 'b_iso_foot_public_spaces'
print_statement = "Isochrones calculated for POI {}"

calculate_isochrones_walk(input_file, output_path, output_filename, print_statement, resume_index=377)
# Out:
# /var/folders/_n/_djf18r57q3482fkc8bbytk80000gn/T/ipykernel_41776/1718344526.py:13: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   poi['centroid'] = poi['geometry'].centroid
# Isochrones calculated for POI 119
# Isochrones calculated for POI 120
# Isochrones calculated for POI 121
# Isochrones calculated for POI 122
# Isochrones calculated for POI 123
# Isochrones calculated for POI 124
# Isochrones calculated for POI 125
# Isochrones calculated for POI 126
# Isochrones calculated for POI 127
# Isochrones calculated for POI 128
# Isochrones calculated for POI 129
# Isochrones calculated for POI 130
# Isochrones calculated for POI 131
# Isochrones calculated for POI 132
# Isochrones calculated for POI 133
# Isochrones calculated for POI 134
# Isochrones calculated for POI 135
# Isochrones calculated for POI 136
# Isochrones calculated for POI 137
# Isochrones calculated for POI 138
# Isochrones calculated for POI 139
# Isochrones calculated for POI 140
# Isochrones calculated for POI 141
# Isochrones calculated for POI 142
# Isochrones calculated for POI 143
# Isochrones calculated for POI 144
# Isochrones calculated for POI 145
# Isochrones calculated for POI 146
# Isochrones calculated for POI 147
# Isochrones calculated for POI 148
# Isochrones calculated for POI 149
# Isochrones calculated for POI 150
# Isochrones calculated for POI 151
# Isochrones calculated for POI 152
# Isochrones calculated for POI 153
# Isochrones calculated for POI 154
# Isochrones calculated for POI 155
# Isochrones calculated for POI 156
# Isochrones calculated for POI 157
# Isochrones calculated for POI 158
# Isochrones calculated for POI 159
# Isochrones calculated for POI 160
# Isochrones calculated for POI 161
# Isochrones calculated for POI 162
# Isochrones calculated for POI 163
# Isochrones calculated for POI 164
# Isochrones calculated for POI 165
# Isochrones calculated for POI 166
# Isochrones calculated for POI 167
# Isochrones calculated for POI 168
# Isochrones calculated for POI 169
# Isochrones calculated for POI 170
# Isochrones calculated for POI 171
# Isochrones calculated for POI 172
# Isochrones calculated for POI 173
# Isochrones calculated for POI 174
# Isochrones calculated for POI 175
# Isochrones calculated for POI 176
# Isochrones calculated for POI 177
# Isochrones calculated for POI 178
# Isochrones calculated for POI 179
# Isochrones calculated for POI 180
# Isochrones calculated for POI 181
# Isochrones calculated for POI 182
# Isochrones calculated for POI 183
# Isochrones calculated for POI 184
# Isochrones calculated for POI 185
# Isochrones calculated for POI 186
# Isochrones calculated for POI 187
# Isochrones calculated for POI 188
# Isochrones calculated for POI 189
# Isochrones calculated for POI 190
# Isochrones calculated for POI 191
# Isochrones calculated for POI 192
# Isochrones calculated for POI 193
# Isochrones calculated for POI 194
# Isochrones calculated for POI 195
# Isochrones calculated for POI 196
# Isochrones calculated for POI 197
# Isochrones calculated for POI 198
# Isochrones calculated for POI 199
# Isochrones calculated for POI 200
# Isochrones calculated for POI 201
# Isochrones calculated for POI 202
# Isochrones calculated for POI 203
# Isochrones calculated for POI 204
# Isochrones calculated for POI 205
# Isochrones calculated for POI 206
# Isochrones calculated for POI 207
# Isochrones calculated for POI 208
# Isochrones calculated for POI 209
# Isochrones calculated for POI 210
# Isochrones calculated for POI 211
# Isochrones calculated for POI 212
# Isochrones calculated for POI 213
# Isochrones calculated for POI 214
# Isochrones calculated for POI 215
# Isochrones calculated for POI 216
# Isochrones calculated for POI 217
# Isochrones calculated for POI 218
# Isochrones calculated for POI 219
# Isochrones calculated for POI 220
# Isochrones calculated for POI 221
# Isochrones calculated for POI 222
# Isochrones calculated for POI 223
# Isochrones calculated for POI 224
# Isochrones calculated for POI 225
# Isochrones calculated for POI 226
# Isochrones calculated for POI 227
# Isochrones calculated for POI 228
# Isochrones calculated for POI 229
# Isochrones calculated for POI 230
# Isochrones calculated for POI 231
# Isochrones calculated for POI 232
# Isochrones calculated for POI 233
# Isochrones calculated for POI 234
# Isochrones calculated for POI 235
# Isochrones calculated for POI 236
# Isochrones calculated for POI 237
# Isochrones calculated for POI 238
# Isochrones calculated for POI 239
# Isochrones calculated for POI 240
# Isochrones calculated for POI 241
# Isochrones calculated for POI 242
# Isochrones calculated for POI 243
# Isochrones calculated for POI 244
# Isochrones calculated for POI 245
# Isochrones calculated for POI 246
# Isochrones calculated for POI 247
# Isochrones calculated for POI 248
# Isochrones calculated for POI 249
# Isochrones calculated for POI 250
# Isochrones calculated for POI 251
# Isochrones calculated for POI 252
# Isochrones calculated for POI 253
# Isochrones calculated for POI 254
# Isochrones calculated for POI 255
# Isochrones calculated for POI 256
# Isochrones calculated for POI 257
# Isochrones calculated for POI 258
# Isochrones calculated for POI 259
# Isochrones calculated for POI 260
# Isochrones calculated for POI 261
# Isochrones calculated for POI 262
# Isochrones calculated for POI 263
# Isochrones calculated for POI 264
# Isochrones calculated for POI 265
# Isochrones calculated for POI 266
# Isochrones calculated for POI 267
# Isochrones calculated for POI 268
# Isochrones calculated for POI 269
# Isochrones calculated for POI 270
# Isochrones calculated for POI 271
# Isochrones calculated for POI 272
# Isochrones calculated for POI 273
# Isochrones calculated for POI 274
# Isochrones calculated for POI 275
# Unable to build an isochrone map for POI. Skipping...
# Isochrones calculated for POI 277
# Isochrones calculated for POI 278
# Isochrones calculated for POI 279
# Isochrones calculated for POI 280
# Isochrones calculated for POI 281
# Isochrones calculated for POI 282
# Isochrones calculated for POI 283
# Isochrones calculated for POI 284
# Isochrones calculated for POI 285
# Isochrones calculated for POI 286
# Isochrones calculated for POI 287
# Isochrones calculated for POI 288
# Isochrones calculated for POI 289
# Isochrones calculated for POI 290
# Isochrones calculated for POI 291
# Isochrones calculated for POI 292
# Isochrones calculated for POI 293
# Isochrones calculated for POI 294
# Isochrones calculated for POI 295
# Isochrones calculated for POI 296
# Isochrones calculated for POI 297
# Isochrones calculated for POI 298
# Isochrones calculated for POI 299
# Isochrones calculated for POI 300
# Isochrones calculated for POI 301
# Isochrones calculated for POI 302
# Isochrones calculated for POI 303
# Isochrones calculated for POI 304
# Isochrones calculated for POI 305
# Isochrones calculated for POI 306
# Isochrones calculated for POI 307
# Isochrones calculated for POI 308
# Isochrones calculated for POI 309
# Isochrones calculated for POI 310
# Isochrones calculated for POI 311
# Isochrones calculated for POI 312
# Isochrones calculated for POI 313
# Isochrones calculated for POI 314
# Isochrones calculated for POI 315
# Isochrones calculated for POI 316
# Isochrones calculated for POI 317
# Isochrones calculated for POI 318
# Isochrones calculated for POI 319
# Isochrones calculated for POI 320
# Isochrones calculated for POI 321
# Isochrones calculated for POI 322
# Isochrones calculated for POI 323
# Isochrones calculated for POI 324
# Isochrones calculated for POI 325
# Isochrones calculated for POI 326
# Isochrones calculated for POI 327
# Isochrones calculated for POI 328
# Isochrones calculated for POI 329
# Isochrones calculated for POI 330
# Isochrones calculated for POI 331
# Isochrones calculated for POI 332
# Isochrones calculated for POI 333
# Isochrones calculated for POI 334
# Isochrones calculated for POI 335
# Isochrones calculated for POI 336
# Isochrones calculated for POI 337
# Isochrones calculated for POI 338
# Isochrones calculated for POI 339
# Isochrones calculated for POI 340
# Isochrones calculated for POI 341
# Isochrones calculated for POI 342
# Isochrones calculated for POI 343
# Isochrones calculated for POI 344
# Isochrones calculated for POI 345
# Isochrones calculated for POI 346
# Isochrones calculated for POI 347
# Isochrones calculated for POI 348
# Isochrones calculated for POI 349
# Isochrones calculated for POI 350
# Isochrones calculated for POI 351
# Isochrones calculated for POI 352
# Isochrones calculated for POI 353
# Isochrones calculated for POI 354
# Isochrones calculated for POI 355
# Isochrones calculated for POI 356
# Isochrones calculated for POI 357
# Isochrones calculated for POI 358
# Isochrones calculated for POI 359
# Isochrones calculated for POI 360
# Isochrones calculated for POI 361
# Isochrones calculated for POI 362
# Isochrones calculated for POI 363
# Isochrones calculated for POI 364
# Isochrones calculated for POI 365
# Isochrones calculated for POI 366
# Isochrones calculated for POI 367
# Isochrones calculated for POI 368
# Isochrones calculated for POI 369
# Isochrones calculated for POI 370
# Isochrones calculated for POI 371
# Isochrones calculated for POI 372
# Isochrones calculated for POI 373
# Isochrones calculated for POI 374
# Isochrones calculated for POI 375
# Isochrones calculated for POI 376
# Isochrones calculated for POI 377
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[22], line 8
#       5 output_filename = 'b_iso_foot_public_spaces'
#       6 print_statement = "Isochrones calculated for POI {}"
# ----> 8 calculate_isochrones_walk(input_file, output_path, output_filename, print_statement, resume_index=119)
#
# Cell In[21], line 82, in calculate_isochrones_walk(input_file, output_path, output_filename, print_statement, resume_index)
#      79     print(print_statement.format(idx))
#      81     # Rate limit handling
# ---> 82     time.sleep(3)  # Add a small delay to avoid rate limits and respect the rate limit
#      84 print("Isochrone calculation completed.")
#
# KeyboardInterrupt:

# %%
## still due, 1/2507, in untitled3

input_file = '../data/output/barcelona/access/combined_public_spaces_wheelchair.geojson'
output_path = '../data/output/barcelona/isochrones_foot_public_spaces/'
output_filename = 'b_iso_foot_public_spaces'
print_statement = "Isochrones calculated for POI {}"

calculate_isochrones_walk(input_file, output_path, output_filename, print_statement, resume_index=1)

# %%
## still due, 1991/3709 --> 2490 --> 2989

input_file = '../data/output/munich/access/combined_public_spaces_wheelchair.geojson'
output_path = '../data/output/munich/isochrones_bike_public_spaces/'
output_filename = 'b_iso_bike_public_spaces'
print_statement = "Isochrones calculated for POI {}"

calculate_isochrones_bike(input_file, output_path, output_filename, print_statement, resume_index=2479)
# Out:
# /var/folders/_n/_djf18r57q3482fkc8bbytk80000gn/T/ipykernel_41776/2289523342.py:13: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   poi['centroid'] = poi['geometry'].centroid
# Isochrones calculated for POI 2479
# Isochrones calculated for POI 2480
# Isochrones calculated for POI 2481
# Isochrones calculated for POI 2482
# Isochrones calculated for POI 2483
# Isochrones calculated for POI 2484
# Isochrones calculated for POI 2485
# Isochrones calculated for POI 2486
# Isochrones calculated for POI 2487
# Isochrones calculated for POI 2488
# Isochrones calculated for POI 2489
# Isochrones calculated for POI 2490
# Isochrones calculated for POI 2491
# Isochrones calculated for POI 2492
# Isochrones calculated for POI 2493
# Isochrones calculated for POI 2494
# Isochrones calculated for POI 2495
# Isochrones calculated for POI 2496
# Isochrones calculated for POI 2497
# Isochrones calculated for POI 2498
# Isochrones calculated for POI 2499
# Isochrones calculated for POI 2500
# Isochrones calculated for POI 2501
# Isochrones calculated for POI 2502
# Isochrones calculated for POI 2503
# Isochrones calculated for POI 2504
# Isochrones calculated for POI 2505
# Isochrones calculated for POI 2506
# Isochrones calculated for POI 2507
# Isochrones calculated for POI 2508
# Isochrones calculated for POI 2509
# Isochrones calculated for POI 2510
# Isochrones calculated for POI 2511
# Isochrones calculated for POI 2512
# Isochrones calculated for POI 2513
# Isochrones calculated for POI 2514
# Isochrones calculated for POI 2515
# Isochrones calculated for POI 2516
# Isochrones calculated for POI 2517
# Isochrones calculated for POI 2518
# Isochrones calculated for POI 2519
# Isochrones calculated for POI 2520
# Isochrones calculated for POI 2521
# Isochrones calculated for POI 2522
# Isochrones calculated for POI 2523
# Isochrones calculated for POI 2524
# Isochrones calculated for POI 2525
# Isochrones calculated for POI 2526
# Isochrones calculated for POI 2527
# Isochrones calculated for POI 2528
# Isochrones calculated for POI 2529
# Isochrones calculated for POI 2530
# Isochrones calculated for POI 2531
# Isochrones calculated for POI 2532
# Isochrones calculated for POI 2533
# Isochrones calculated for POI 2534
# Isochrones calculated for POI 2535
# Isochrones calculated for POI 2536
# Isochrones calculated for POI 2537
# Isochrones calculated for POI 2538
# Isochrones calculated for POI 2539
# Isochrones calculated for POI 2540
# Unable to build an isochrone map for POI. Skipping...
# Isochrones calculated for POI 2542
# Isochrones calculated for POI 2543
# Isochrones calculated for POI 2544
# Isochrones calculated for POI 2545
# Isochrones calculated for POI 2546
# Isochrones calculated for POI 2547
# Isochrones calculated for POI 2548
# Isochrones calculated for POI 2549
# Isochrones calculated for POI 2550
# Isochrones calculated for POI 2551
# Isochrones calculated for POI 2552
# Isochrones calculated for POI 2553
# Isochrones calculated for POI 2554
# Isochrones calculated for POI 2555
# Isochrones calculated for POI 2556
# Isochrones calculated for POI 2557
# Isochrones calculated for POI 2558
# Isochrones calculated for POI 2559
# Isochrones calculated for POI 2560
# Isochrones calculated for POI 2561
# Isochrones calculated for POI 2562
# Isochrones calculated for POI 2563
# Isochrones calculated for POI 2564
# Isochrones calculated for POI 2565
# Unable to build an isochrone map for POI. Skipping...
# Isochrones calculated for POI 2567
# Isochrones calculated for POI 2568
# Isochrones calculated for POI 2569
# Isochrones calculated for POI 2570
# Isochrones calculated for POI 2571
# Isochrones calculated for POI 2572
# Isochrones calculated for POI 2573
# Isochrones calculated for POI 2574
# Isochrones calculated for POI 2575
# Isochrones calculated for POI 2576
# Isochrones calculated for POI 2577
# Isochrones calculated for POI 2578
# Isochrones calculated for POI 2579
# Isochrones calculated for POI 2580
# Isochrones calculated for POI 2581
# Isochrones calculated for POI 2582
# Isochrones calculated for POI 2583
# Isochrones calculated for POI 2584
# Isochrones calculated for POI 2585
# Isochrones calculated for POI 2586
# Unable to build an isochrone map for POI. Skipping...
# Isochrones calculated for POI 2588
# Isochrones calculated for POI 2589
# Isochrones calculated for POI 2590
# Isochrones calculated for POI 2591
# Isochrones calculated for POI 2592
# Isochrones calculated for POI 2593
# Isochrones calculated for POI 2594
# Isochrones calculated for POI 2595
# Isochrones calculated for POI 2596
# Isochrones calculated for POI 2597
# Isochrones calculated for POI 2598
# Isochrones calculated for POI 2599
# Isochrones calculated for POI 2600
# Isochrones calculated for POI 2601
# Isochrones calculated for POI 2602
# Isochrones calculated for POI 2603
# Isochrones calculated for POI 2604
# Isochrones calculated for POI 2605
# Isochrones calculated for POI 2606
# Isochrones calculated for POI 2607
# Isochrones calculated for POI 2608
# Isochrones calculated for POI 2609
# Isochrones calculated for POI 2610
# Isochrones calculated for POI 2611
# Isochrones calculated for POI 2612
# Isochrones calculated for POI 2613
# Isochrones calculated for POI 2614
# Isochrones calculated for POI 2615
# Isochrones calculated for POI 2616
# Isochrones calculated for POI 2617
# Isochrones calculated for POI 2618
# Isochrones calculated for POI 2619
# Isochrones calculated for POI 2620
# Isochrones calculated for POI 2621
# Isochrones calculated for POI 2622
# Isochrones calculated for POI 2623
# Isochrones calculated for POI 2624
# Isochrones calculated for POI 2625
# Isochrones calculated for POI 2626
# Isochrones calculated for POI 2627
# Isochrones calculated for POI 2628
# Isochrones calculated for POI 2629
# Unable to build an isochrone map for POI. Skipping...
# Isochrones calculated for POI 2631
# Isochrones calculated for POI 2632
# Unable to build an isochrone map for POI. Skipping...
# Isochrones calculated for POI 2634
# Isochrones calculated for POI 2635
# Isochrones calculated for POI 2636
# Isochrones calculated for POI 2637
# Isochrones calculated for POI 2638
# Isochrones calculated for POI 2639
# Isochrones calculated for POI 2640
# Isochrones calculated for POI 2641
# Isochrones calculated for POI 2642
# Isochrones calculated for POI 2643
# Isochrones calculated for POI 2644
# Isochrones calculated for POI 2645
# Isochrones calculated for POI 2646
# Isochrones calculated for POI 2647
# Isochrones calculated for POI 2648
# Isochrones calculated for POI 2649
# Isochrones calculated for POI 2650
# Isochrones calculated for POI 2651
# Isochrones calculated for POI 2652
# Isochrones calculated for POI 2653
# Isochrones calculated for POI 2654
# Isochrones calculated for POI 2655
# Isochrones calculated for POI 2656
# Isochrones calculated for POI 2657
# Isochrones calculated for POI 2658
# Isochrones calculated for POI 2659
# Isochrones calculated for POI 2660
# Isochrones calculated for POI 2661
# Isochrones calculated for POI 2662
# Isochrones calculated for POI 2663
# Isochrones calculated for POI 2664
# Isochrones calculated for POI 2665
# Isochrones calculated for POI 2666
# Isochrones calculated for POI 2667
# Isochrones calculated for POI 2668
# Isochrones calculated for POI 2669
# Isochrones calculated for POI 2670
# Isochrones calculated for POI 2671
# Isochrones calculated for POI 2672
# Isochrones calculated for POI 2673
# Isochrones calculated for POI 2674
# Isochrones calculated for POI 2675
# Isochrones calculated for POI 2676
# Isochrones calculated for POI 2677
# Isochrones calculated for POI 2678
# Isochrones calculated for POI 2679
# Isochrones calculated for POI 2680
# Isochrones calculated for POI 2681
# Isochrones calculated for POI 2682
# Isochrones calculated for POI 2683
# Isochrones calculated for POI 2684
# Isochrones calculated for POI 2685
# Isochrones calculated for POI 2686
# Isochrones calculated for POI 2687
# Isochrones calculated for POI 2688
# Isochrones calculated for POI 2689
# Isochrones calculated for POI 2690
# Isochrones calculated for POI 2691
# Isochrones calculated for POI 2692
# Isochrones calculated for POI 2693
# Isochrones calculated for POI 2694
# Isochrones calculated for POI 2695
# Isochrones calculated for POI 2696
# Isochrones calculated for POI 2697
# Isochrones calculated for POI 2698
# Isochrones calculated for POI 2699
# Isochrones calculated for POI 2700
# Isochrones calculated for POI 2701
# Isochrones calculated for POI 2702
# Isochrones calculated for POI 2703
# Isochrones calculated for POI 2704
# Isochrones calculated for POI 2705
# Isochrones calculated for POI 2706
# Isochrones calculated for POI 2707
# Isochrones calculated for POI 2708
# Isochrones calculated for POI 2709
# Isochrones calculated for POI 2710
# Isochrones calculated for POI 2711
# Isochrones calculated for POI 2712
# Isochrones calculated for POI 2713
# Isochrones calculated for POI 2714
# Isochrones calculated for POI 2715
# Isochrones calculated for POI 2716
# Isochrones calculated for POI 2717
# Isochrones calculated for POI 2718
# Isochrones calculated for POI 2719
# Isochrones calculated for POI 2720
# Isochrones calculated for POI 2721
# Isochrones calculated for POI 2722
# Isochrones calculated for POI 2723
# Isochrones calculated for POI 2724
# Isochrones calculated for POI 2725
# Isochrones calculated for POI 2726
# Isochrones calculated for POI 2727
# Isochrones calculated for POI 2728
# Isochrones calculated for POI 2729
# Isochrones calculated for POI 2730
# Isochrones calculated for POI 2731
# Isochrones calculated for POI 2732
# Isochrones calculated for POI 2733
# Unable to build an isochrone map for POI. Skipping...
# Isochrones calculated for POI 2735
# Isochrones calculated for POI 2736
# Isochrones calculated for POI 2737
# Isochrones calculated for POI 2738
# Isochrones calculated for POI 2739
# Isochrones calculated for POI 2740
# Unable to build an isochrone map for POI. Skipping...
# Isochrones calculated for POI 2742
# Isochrones calculated for POI 2743
# Isochrones calculated for POI 2744
# Isochrones calculated for POI 2745
# Isochrones calculated for POI 2746
# Isochrones calculated for POI 2747
# Isochrones calculated for POI 2748
# Isochrones calculated for POI 2749
# Isochrones calculated for POI 2750
# Isochrones calculated for POI 2751
# Isochrones calculated for POI 2752
# Isochrones calculated for POI 2753
# Isochrones calculated for POI 2754
# Isochrones calculated for POI 2755
# Unable to build an isochrone map for POI. Skipping...
# Unable to build an isochrone map for POI. Skipping...
# Isochrones calculated for POI 2758
# Isochrones calculated for POI 2759
# Isochrones calculated for POI 2760
# Isochrones calculated for POI 2761
# Isochrones calculated for POI 2762
# Isochrones calculated for POI 2763
# Isochrones calculated for POI 2764
# Isochrones calculated for POI 2765
# Isochrones calculated for POI 2766
# Isochrones calculated for POI 2767
# Isochrones calculated for POI 2768
# Isochrones calculated for POI 2769
# Isochrones calculated for POI 2770
# Isochrones calculated for POI 2771
# Isochrones calculated for POI 2772
# Isochrones calculated for POI 2773
# Isochrones calculated for POI 2774
# Isochrones calculated for POI 2775
# Isochrones calculated for POI 2776
# Isochrones calculated for POI 2777
# Isochrones calculated for POI 2778
# Isochrones calculated for POI 2779
# Isochrones calculated for POI 2780
# Isochrones calculated for POI 2781
# Isochrones calculated for POI 2782
# Isochrones calculated for POI 2783
# Isochrones calculated for POI 2784
# Isochrones calculated for POI 2785
# Isochrones calculated for POI 2786
# Isochrones calculated for POI 2787
# Isochrones calculated for POI 2788
# Isochrones calculated for POI 2789
# Isochrones calculated for POI 2790
# Isochrones calculated for POI 2791
# Isochrones calculated for POI 2792
# Isochrones calculated for POI 2793
# Isochrones calculated for POI 2794
# Isochrones calculated for POI 2795
# Isochrones calculated for POI 2796
# Unable to build an isochrone map for POI. Skipping...
# Isochrones calculated for POI 2798
# Isochrones calculated for POI 2799
# Isochrones calculated for POI 2800
# Isochrones calculated for POI 2801
# Isochrones calculated for POI 2802
# Isochrones calculated for POI 2803
# Isochrones calculated for POI 2804
# Isochrones calculated for POI 2805
# Isochrones calculated for POI 2806
# Isochrones calculated for POI 2807
# Isochrones calculated for POI 2808
# Isochrones calculated for POI 2809
# Isochrones calculated for POI 2810
# Isochrones calculated for POI 2811
# Isochrones calculated for POI 2812
# Isochrones calculated for POI 2813
# Isochrones calculated for POI 2814
# Isochrones calculated for POI 2815
# Isochrones calculated for POI 2816
# Isochrones calculated for POI 2817
# Isochrones calculated for POI 2818
# Isochrones calculated for POI 2819
# Isochrones calculated for POI 2820
# Isochrones calculated for POI 2821
# Isochrones calculated for POI 2822
# Isochrones calculated for POI 2823
# Isochrones calculated for POI 2824
# Isochrones calculated for POI 2825
# Isochrones calculated for POI 2826
# Isochrones calculated for POI 2827
# Isochrones calculated for POI 2828
# Isochrones calculated for POI 2829
# Isochrones calculated for POI 2830
# Isochrones calculated for POI 2831
# Isochrones calculated for POI 2832
# Isochrones calculated for POI 2833
# Isochrones calculated for POI 2834
# Isochrones calculated for POI 2835
# Isochrones calculated for POI 2836
# Isochrones calculated for POI 2837
# Isochrones calculated for POI 2838
# Isochrones calculated for POI 2839
# Isochrones calculated for POI 2840
# Isochrones calculated for POI 2841
# Isochrones calculated for POI 2842
# Isochrones calculated for POI 2843
# Isochrones calculated for POI 2844
# Isochrones calculated for POI 2845
# Isochrones calculated for POI 2846
# Isochrones calculated for POI 2847
# Isochrones calculated for POI 2848
# Isochrones calculated for POI 2849
# Isochrones calculated for POI 2850
# Isochrones calculated for POI 2851
# Isochrones calculated for POI 2852
# Isochrones calculated for POI 2853
# Isochrones calculated for POI 2854
# Isochrones calculated for POI 2855
# Isochrones calculated for POI 2856
# Isochrones calculated for POI 2857
# Isochrones calculated for POI 2858
# Isochrones calculated for POI 2859
# Isochrones calculated for POI 2860
# Isochrones calculated for POI 2861
# Isochrones calculated for POI 2862
# Isochrones calculated for POI 2863
# Isochrones calculated for POI 2864
# Isochrones calculated for POI 2865
# Isochrones calculated for POI 2866
# Isochrones calculated for POI 2867
# Isochrones calculated for POI 2868
# Isochrones calculated for POI 2869
# Isochrones calculated for POI 2870
# Isochrones calculated for POI 2871
# Isochrones calculated for POI 2872
# Isochrones calculated for POI 2873
# Isochrones calculated for POI 2874
# Isochrones calculated for POI 2875
# Isochrones calculated for POI 2876
# Isochrones calculated for POI 2877
# Isochrones calculated for POI 2878
# Isochrones calculated for POI 2879
# Isochrones calculated for POI 2880
# Isochrones calculated for POI 2881
# Isochrones calculated for POI 2882
# Isochrones calculated for POI 2883
# Isochrones calculated for POI 2884
# Isochrones calculated for POI 2885
# Isochrones calculated for POI 2886
# Isochrones calculated for POI 2887
# Isochrones calculated for POI 2888
# Isochrones calculated for POI 2889
# Isochrones calculated for POI 2890
# Isochrones calculated for POI 2891
# Isochrones calculated for POI 2892
# Isochrones calculated for POI 2893
# Isochrones calculated for POI 2894
# Isochrones calculated for POI 2895
# Isochrones calculated for POI 2896
# Isochrones calculated for POI 2897
# Isochrones calculated for POI 2898
# Isochrones calculated for POI 2899
# Isochrones calculated for POI 2900
# Isochrones calculated for POI 2901
# Isochrones calculated for POI 2902
# Isochrones calculated for POI 2903
# Isochrones calculated for POI 2904
# Isochrones calculated for POI 2905
# Isochrones calculated for POI 2906
# Isochrones calculated for POI 2907
# Isochrones calculated for POI 2908
# Isochrones calculated for POI 2909
# Isochrones calculated for POI 2910
# Isochrones calculated for POI 2911
# Isochrones calculated for POI 2912
# Isochrones calculated for POI 2913
# Isochrones calculated for POI 2914
# Isochrones calculated for POI 2915
# Isochrones calculated for POI 2916
# Isochrones calculated for POI 2917
# Isochrones calculated for POI 2918
# Isochrones calculated for POI 2919
# Isochrones calculated for POI 2920
# Isochrones calculated for POI 2921
# Isochrones calculated for POI 2922
# Isochrones calculated for POI 2923
# Isochrones calculated for POI 2924
# Isochrones calculated for POI 2925
# Isochrones calculated for POI 2926
# Isochrones calculated for POI 2927
# Isochrones calculated for POI 2928
# Isochrones calculated for POI 2929
# Isochrones calculated for POI 2930
# Isochrones calculated for POI 2931
# Isochrones calculated for POI 2932
# Isochrones calculated for POI 2933
# Isochrones calculated for POI 2934
# Isochrones calculated for POI 2935
# Isochrones calculated for POI 2936
# Isochrones calculated for POI 2937
# Isochrones calculated for POI 2938
# Isochrones calculated for POI 2939
# Isochrones calculated for POI 2940
# Isochrones calculated for POI 2941
# Isochrones calculated for POI 2942
# Isochrones calculated for POI 2943
# Isochrones calculated for POI 2944
# Isochrones calculated for POI 2945
# Isochrones calculated for POI 2946
# Isochrones calculated for POI 2947
# Isochrones calculated for POI 2948
# Isochrones calculated for POI 2949
# Isochrones calculated for POI 2950
# Isochrones calculated for POI 2951
# Isochrones calculated for POI 2952
# Isochrones calculated for POI 2953
# Isochrones calculated for POI 2954
# Isochrones calculated for POI 2955
# Unable to build an isochrone map for POI. Skipping...
# Isochrones calculated for POI 2957
# Isochrones calculated for POI 2958
# Isochrones calculated for POI 2959
# Isochrones calculated for POI 2960
# Isochrones calculated for POI 2961
# Isochrones calculated for POI 2962
# Isochrones calculated for POI 2963
# Isochrones calculated for POI 2964
# Isochrones calculated for POI 2965
# Isochrones calculated for POI 2966
# Isochrones calculated for POI 2967
# Isochrones calculated for POI 2968
# Isochrones calculated for POI 2969
# Isochrones calculated for POI 2970
# Unable to build an isochrone map for POI. Skipping...
# Isochrones calculated for POI 2972
# Isochrones calculated for POI 2973
# Isochrones calculated for POI 2974
# Isochrones calculated for POI 2975
# Isochrones calculated for POI 2976
# Isochrones calculated for POI 2977
# Isochrones calculated for POI 2978
# ---------------------------------------------------------------------------
# ApiError                                  Traceback (most recent call last)
# Cell In[42], line 8
#       5 output_filename = 'b_iso_bike_public_spaces'
#       6 print_statement = "Isochrones calculated for POI {}"
# ----> 8 calculate_isochrones_bike(input_file, output_path, output_filename, print_statement, resume_index=2479)
#
# Cell In[41], line 62, in calculate_isochrones_bike(input_file, output_path, output_filename, print_statement, resume_index)
#      59 coordinate = (lon, lat)
#      61 # Calculate isochrones with retry mechanism
# ---> 62 isochrones = calculate_isochrones_with_retry(coordinate)
#      63 if isochrones is None:
#      64     continue  # Skip the poi if isochrones cannot be calculated
#
# Cell In[41], line 48, in calculate_isochrones_bike.<locals>.calculate_isochrones_with_retry(coordinate)
#      46             return None
#      47         else:
# ---> 48             raise e  # Re-raise the exception if it's not related to rate limit exceeded
#      49 return None
#
# Cell In[41], line 38, in calculate_isochrones_bike.<locals>.calculate_isochrones_with_retry(coordinate)
#      36 for attempt in range(retries):
#      37     try:
# ---> 38         isochrones = client.isochrones(locations=[coordinate], profile=profile, range_type=range_type, range=range_seconds, attributes=['total_pop'])
#      39         return isochrones
#      40     except ApiError as e:
#
# File ~/anaconda3/lib/python3.11/site-packages/openrouteservice/client.py:299, in _make_api_method.<locals>.wrapper(*args, **kwargs)
#     296 @functools.wraps(func)
#     297 def wrapper(*args, **kwargs):
#     298     args[0]._extra_params = kwargs.pop("extra_params", None)
# --> 299     result = func(*args, **kwargs)
#     300     try:
#     301         del args[0]._extra_params
#
# File ~/anaconda3/lib/python3.11/site-packages/openrouteservice/isochrones.py:132, in isochrones(client, locations, profile, range_type, range, intervals, segments, interval, units, location_type, smoothing, attributes, validate, dry_run)
#     129 if attributes:
#     130     params["attributes"] = attributes
# --> 132 return client.request("/v2/isochrones/" + profile + '/geojson', {}, post_json=params, dry_run=dry_run)
#
# File ~/anaconda3/lib/python3.11/site-packages/openrouteservice/client.py:204, in Client.request(self, url, get_params, first_request_time, retry_counter, requests_kwargs, post_json, dry_run)
#     200     return self.request(url, get_params, first_request_time,
#     201                         retry_counter + 1, requests_kwargs, post_json)
#     203 try:
# --> 204     result = self._get_body(response)
#     206     return result
#     207 except exceptions._RetriableRequest as e:
#
# File ~/anaconda3/lib/python3.11/site-packages/openrouteservice/client.py:242, in Client._get_body(response)
#     237     raise exceptions._OverQueryLimit(
#     238         status_code,
#     239         body
#     240     )
#     241 if status_code != 200:
# --> 242     raise exceptions.ApiError(
#     243         status_code,
#     244         body
#     245     )
#     247 return body
#
# ApiError: 403 ({'error': 'Quota exceeded'})
